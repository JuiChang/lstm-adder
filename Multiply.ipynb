# %%
from keras.models import Sequential
from keras import layers
from keras.models import Sequential
from keras.layers import LSTM, Dense, Lambda, Dropout, GRU, TimeDistributed
from keras.optimizers import Adam, RMSprop
import numpy as np
from six.moves import range
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Parameters Config

# %%
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
TRAINING_SIZE = 80000
DIGITS = 3
REVERSE = False
MAXLEN = DIGITS + 1 + DIGITS
chars = '0123456789* '
RNN = layers.LSTM
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 1

# %%
class CharacterTable(object):
    def __init__(self, chars):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
    
    # one-hot
    def encode(self, C, num_rows):
        # x is 2D...
        x = np.zeros((num_rows, len(self.chars)))
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1  # why showing True/False below ?
        return x
    
    def decode(self, x, calc_argmax=True):
        if calc_argmax:
            x = x.argmax(axis=-1)
        return "".join(self.indices_char[i] for i in x)

# %%
ctable = CharacterTable(chars)

# %%
ctable.indices_char
# Out:
# {0: ' ',
#  1: '*',
#  2: '0',
#  3: '1',
#  4: '2',
#  5: '3',
#  6: '4',
#  7: '5',
#  8: '6',
#  9: '7',
#  10: '8',
#  11: '9'}

# %% [markdown]
# # Data Generation

# %%
# Generate the two lists, i.e. question and answer in p5 of the ppt

questions = []
expected = []
seen = set() #?

print('Generating data...')
while len(questions) < TRAINING_SIZE:
    
    # ?
    f = lambda: int(''.join(np.random.choice(list('0123456789')) for i in range(np.random.randint(1, DIGITS + 1))))
    a, b = f(), f()
    
    # avoid duplication
    key = tuple(sorted((a, b)))
    if key in seen:
        continue
    seen.add(key)
    
    q = '{}*{}'.format(a, b)
    query = q + ' ' * (MAXLEN - len(q))
    ans = str(a * b)
    ans += ' ' * (DIGITS + 3 - len(ans))
    
    # ?
    if REVERSE:
        query = query[::-1]
        
    questions.append(query)
    expected.append(ans)
    
print('Total addition questions:', len(questions))
# Out:
# Generating data...
# Total addition questions: 80000

# %%
print(questions[:5], expected[:5])
# Out:
# ['37*98  ', '9*36   ', '18*7   ', '5*4    ', '5*40   '] ['3626  ', '324   ', '126   ', '20    ', '200   ']

# %% [markdown]
# # Processing

# %%
print('Vectorization...')
x = np.zeros((len(questions), MAXLEN, len(chars)), dtype=np.bool)
y = np.zeros((len(expected), DIGITS + 3, len(chars)), dtype=np.bool)

for i, sentence in enumerate(questions):
    x[i] = ctable.encode(sentence, MAXLEN)
for i, sentence in enumerate(expected):
    y[i] = ctable.encode(sentence, DIGITS + 3)
# Out:
# Vectorization...

# %%
# shuffle the data
indices = np.arange(len(y))
np.random.shuffle(indices)
x = x[indices]
y = y[indices]

# train_test_split
# take the first 20000 element
train_x = x[:20000]
train_y = y[:20000]
# take the elements other than first 20000
test_x = x[20000:]
test_y = y[20000:]

# val set is about 1/10 of the train set
split_at = len(train_x) - len(train_x) // 10
(x_train, x_val) = train_x[:split_at], train_x[split_at:]
(y_train, y_val) = train_y[:split_at], train_y[split_at:]

print('Training Data:')
print(x_train.shape)
print(y_train.shape)

print('Validation Data:')
print(x_val.shape)
print(y_val.shape)

print('Testing Data:')
print(test_x.shape)
print(test_y.shape)
# Out:
# Training Data:
# (18000, 7, 12)
# (18000, 6, 12)
# Validation Data:
# (2000, 7, 12)
# (2000, 6, 12)
# Testing Data:
# (60000, 7, 12)
# (60000, 6, 12)

# %%
print("input: ", x_train[:1], '\n\n', "label: ", y_train[:1])
# Out:
# input:  [[[False False False False False False False False False False  True
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False  True False False False False False False False
#    False]
#   [False False False  True False False False False False False False
#    False]
#   [ True False False False False False False False False False False
#    False]]]
#
#  label:  [[[False False False False False False False False False False False
#     True]
#   [False False False False False False False  True False False False
#    False]
#   [False False False False  True False False False False False False
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [ True False False False False False False False False False False
#    False]
#   [ True False False False False False False False False False False
#    False]]]

# %% [markdown]
# # Build Model

# %%
print('Build model...')

############################################
##### Build your own model here ############
############################################
model = Sequential()
model.add(LSTM(HIDDEN_SIZE, input_shape=(MAXLEN, len(chars))))
model.add(layers.RepeatVector(DIGITS + 3))
# model.add(Lambda(lambda x: x[:, -(DIGITS + 1):, :]))
model.add(LSTM(HIDDEN_SIZE, return_sequences=True))
model.add(TimeDistributed(Dense(len(chars), activation='softmax')))
optimizer = Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer,
              metrics=['accuracy'])

model.summary()
# Out:
# Build model...
# WARNING:tensorflow:From /Users/juichang/py_36_env/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               72192
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 6, 128)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 6, 128)            131584
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 6, 12)             1548
# =================================================================
# Total params: 205,324
# Trainable params: 205,324
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss = list()
val_loss = list()
val_ratio = list()
acc = list()

# %% [markdown]
# # Training

# %%
for iteration in range(100):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    
    history = model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=1,
              validation_data=(x_val, y_val))
    loss.append(history.history['loss'][0])
    val_loss.append(history.history['val_loss'][0])
    acc.append(history.history['acc'][0])
    
    # test on 10 datapoint in the val. set (1 per iter.)
    correct_count = 0
    for i in range(10):
        ind = np.random.randint(0, len(x_val))
        rowx, rowy = x_val[np.array([ind])], y_val[np.array([ind])]
        
        preds = model.predict_classes(rowx, verbose=0)
        
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        
        # as ppt p7
        print('Q', q[::-1] if REVERSE else q, end=' ')
        print('T', correct, end=' ')
        if correct == guess:
            print(colors.ok + '☑' + colors.close, end=' ')
            correct_count += 1
        else:
            print(colors.fail + '☒' + colors.close, end=' ')
        print(guess)
    val_ratio.append(correct_count / 10)
# Out:
# --------------------------------------------------
# Iteration 0
# WARNING:tensorflow:From /Users/juichang/py_36_env/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 526us/step - loss: 2.0150 - acc: 0.2693 - val_loss: 1.8733 - val_acc: 0.3065
# Q 447*900 T 402300 ☒ 110000
# Q 276*82  T 22632  ☒ 11460
# Q 645*385 T 248325 ☒ 115500
# Q 979*360 T 352440 ☒ 111000
# Q 964*78  T 75192  ☒ 11166
# Q 112*636 T 71232  ☒ 11166
# Q 90*924  T 83160  ☒ 11000
# Q 210*62  T 13020  ☒ 1100
# Q 62*402  T 24924  ☒ 11000
# Q 526*16  T 8416   ☒ 1140
#
# --------------------------------------------------
# Iteration 1
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 306us/step - loss: 1.8519 - acc: 0.3117 - val_loss: 1.8384 - val_acc: 0.3124
# Q 240*380 T 91200  ☒ 120000
# Q 803*77  T 61831  ☒ 11000
# Q 886*964 T 854104 ☒ 126644
# Q 180*26  T 4680   ☒ 1200
# Q 431*125 T 53875  ☒ 11772
# Q 8*987   T 7896   ☒ 1242
# Q 361*502 T 181222 ☒ 120000
# Q 3*805   T 2415   ☒ 1000
# Q 92*490  T 45080  ☒ 12000
# Q 990*265 T 262350 ☒ 110000
#
# --------------------------------------------------
# Iteration 2
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 388us/step - loss: 1.8196 - acc: 0.3173 - val_loss: 1.8011 - val_acc: 0.3234
# Q 558*13  T 7254   ☒ 11755
# Q 59*697  T 41123  ☒ 11775
# Q 232*87  T 20184  ☒ 1282
# Q 335*30  T 10050  ☒ 11000
# Q 2*996   T 1992   ☒ 1288
# Q 22*16   T 352    ☒ 122
# Q 32*29   T 928    ☒ 128
# Q 253*32  T 8096   ☒ 1272
# Q 61*593  T 36173  ☒ 11755
# Q 795*329 T 261555 ☒ 110778
#
# --------------------------------------------------
# Iteration 3
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 401us/step - loss: 1.7989 - acc: 0.3205 - val_loss: 1.7818 - val_acc: 0.3254
# Q 490*251 T 122990 ☒ 111100
# Q 41*164  T 6724   ☒ 1186
# Q 115*45  T 5175   ☒ 1155
# Q 709*896 T 635264 ☒ 136660
# Q 97*34   T 3298   ☒ 1186
# Q 458*47  T 21526  ☒ 15322
# Q 93*736  T 68448  ☒ 11116
# Q 676*669 T 452244 ☒ 155066
# Q 77*462  T 35574  ☒ 15866
# Q 575*33  T 18975  ☒ 15555
#
# --------------------------------------------------
# Iteration 4
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 332us/step - loss: 1.7758 - acc: 0.3257 - val_loss: 1.7608 - val_acc: 0.3262
# Q 495*549 T 271755 ☒ 123340
# Q 346*20  T 6920   ☒ 18800
# Q 24*467  T 11208  ☒ 10044
# Q 281*39  T 10959  ☒ 10073
# Q 559*499 T 278941 ☒ 123335
# Q 868*3   T 2604   ☒ 1444
# Q 779*84  T 65436  ☒ 14444
# Q 283*53  T 14999  ☒ 10055
# Q 160*55  T 8800   ☒ 1550
# Q 1*640   T 640    ☒ 120
#
# --------------------------------------------------
# Iteration 5
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 333us/step - loss: 1.7384 - acc: 0.3336 - val_loss: 1.7297 - val_acc: 0.3421
# Q 775*742 T 575050 ☒ 266662
# Q 9*308   T 2772   ☒ 1460
# Q 962*760 T 731120 ☒ 233660
# Q 195*68  T 13260  ☒ 13620
# Q 2*104   T 208    ☒ 120
# Q 370*86  T 31820  ☒ 11660
# Q 347*765 T 265455 ☒ 126655
# Q 723*52  T 37596  ☒ 10562
# Q 45*641  T 28845  ☒ 12362
# Q 733*660 T 483780 ☒ 123660
#
# --------------------------------------------------
# Iteration 6
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 346us/step - loss: 1.7034 - acc: 0.3446 - val_loss: 1.6809 - val_acc: 0.3558
# Q 954*81  T 77274  ☒ 33374
# Q 283*983 T 278189 ☒ 100077
# Q 57*432  T 24624  ☒ 10334
# Q 112*70  T 7840   ☒ 1140
# Q 14*946  T 13244  ☒ 11444
# Q 25*330  T 8250   ☒ 1155
# Q 97*658  T 63826  ☒ 33344
# Q 361*502 T 181222 ☒ 111744
# Q 629*825 T 518925 ☒ 121755
# Q 809*19  T 15371  ☒ 17776
#
# --------------------------------------------------
# Iteration 7
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 347us/step - loss: 1.6522 - acc: 0.3627 - val_loss: 1.6415 - val_acc: 0.3653
# Q 8*611   T 4888   ☒ 1797
# Q 480*78  T 37440  ☒ 26660
# Q 57*729  T 41553  ☒ 22037
# Q 87*833  T 72471  ☒ 55577
# Q 87*490  T 42630  ☒ 57770
# Q 302*244 T 73688  ☒ 11152
# Q 660*947 T 625020 ☒ 377720
# Q 99*663  T 65637  ☒ 55597
# Q 13*20   T 260    ☒ 100
# Q 6*976   T 5856   ☒ 5666
#
# --------------------------------------------------
# Iteration 8
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 393us/step - loss: 1.6071 - acc: 0.3770 - val_loss: 1.6017 - val_acc: 0.3779
# Q 14*529  T 7406   ☒ 1022
# Q 189*858 T 162162 ☒ 222026
# Q 1*21    T 21     ☒ 1
# Q 593*32  T 18976  ☒ 22226
# Q 587*50  T 29350  ☒ 43300
# Q 202*444 T 89688  ☒ 11962
# Q 691*71  T 49061  ☒ 36237
# Q 39*715  T 27885  ☒ 12275
# Q 591*76  T 44916  ☒ 46626
# Q 102*76  T 7752   ☒ 1142
#
# --------------------------------------------------
# Iteration 9
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 360us/step - loss: 1.5675 - acc: 0.3928 - val_loss: 1.5416 - val_acc: 0.4001
# Q 75*899  T 67425  ☒ 54975
# Q 80*17   T 1360   ☒ 1800
# Q 349*553 T 192997 ☒ 112411
# Q 77*246  T 18942  ☒ 12222
# Q 41*91   T 3731   ☒ 2991
# Q 383*94  T 36002  ☒ 22922
# Q 522*659 T 343998 ☒ 304442
# Q 1*640   T 640    ☒ 180
# Q 430*85  T 36550  ☒ 39750
# Q 928*115 T 106720 ☒ 11170
#
# --------------------------------------------------
# Iteration 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 379us/step - loss: 1.5117 - acc: 0.4102 - val_loss: 1.4843 - val_acc: 0.4073
# Q 972*399 T 387828 ☒ 398088
# Q 97*648  T 62856  ☒ 56662
# Q 615*93  T 57195  ☒ 39335
# Q 514*65  T 33410  ☒ 30380
# Q 77*499  T 38423  ☒ 30039
# Q 777*29  T 22533  ☒ 20099
# Q 48*472  T 22656  ☒ 22364
# Q 880*451 T 396880 ☒ 398980
# Q 869*888 T 771672 ☒ 566062
# Q 214*811 T 173554 ☒ 116068
#
# --------------------------------------------------
# Iteration 11
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 396us/step - loss: 1.4544 - acc: 0.4257 - val_loss: 1.4389 - val_acc: 0.4283
# Q 932*538 T 501416 ☒ 416954
# Q 963*700 T 674100 ☒ 666700
# Q 524*3   T 1572   ☒ 1444
# Q 493*86  T 42398  ☒ 38004
# Q 70*374  T 26180  ☒ 28440
# Q 733*660 T 483780 ☒ 586660
# Q 59*674  T 39766  ☒ 40404
# Q 204*849 T 173196 ☒ 124634
# Q 23*827  T 19021  ☒ 25231
# Q 831*39  T 32409  ☒ 30031
#
# --------------------------------------------------
# Iteration 12
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 385us/step - loss: 1.4152 - acc: 0.4375 - val_loss: 1.4054 - val_acc: 0.4360
# Q 413*66  T 27258  ☒ 22282
# Q 460*20  T 9200   ☒ 1200
# Q 68*8    T 544    ☒ 564
# Q 457*634 T 289738 ☒ 332002
# Q 35*871  T 30485  ☒ 33225
# Q 229*18  T 4122   ☒ 6644
# Q 66*155  T 10230  ☒ 11100
# Q 15*291  T 4365   ☒ 5575
# Q 417*8   T 3336   ☒ 3222
# Q 923*135 T 124605 ☒ 114675
#
# --------------------------------------------------
# Iteration 13
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 382us/step - loss: 1.3886 - acc: 0.4490 - val_loss: 1.3877 - val_acc: 0.4391
# Q 2*634   T 1268   ☒ 1106
# Q 438*530 T 232140 ☒ 224640
# Q 86*251  T 21586  ☒ 25004
# Q 90*518  T 46620  ☒ 49640
# Q 561*32  T 17952  ☒ 15004
# Q 402*5   T 2010   ☒ 2000
# Q 38*27   T 1026   ☒ 1168
# Q 56*629  T 35224  ☒ 32404
# Q 13*222  T 2886   ☒ 4446
# Q 156*1   T 156    ☒ 444
#
# --------------------------------------------------
# Iteration 14
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 399us/step - loss: 1.3665 - acc: 0.4576 - val_loss: 1.3638 - val_acc: 0.4523
# Q 229*33  T 7557   ☒ 7009
# Q 517*83  T 42911  ☒ 30701
# Q 68*274  T 18632  ☒ 17726
# Q 455*104 T 47320  ☒ 56750
# Q 252*591 T 148932 ☒ 150062
# Q 42*382  T 16044  ☒ 14756
# Q 905*5   T 4525   ☒ 4455
# Q 943*94  T 88642  ☒ 77776
# Q 146*205 T 29930  ☒ 42200
# Q 41*91   T 3731   ☒ 3433
#
# --------------------------------------------------
# Iteration 15
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 401us/step - loss: 1.3446 - acc: 0.4670 - val_loss: 1.3595 - val_acc: 0.4540
# Q 649*936 T 607464 ☒ 533002
# Q 181*45  T 8145   ☒ 7075
# Q 373*16  T 5968   ☒ 7774
# Q 150*804 T 120600 ☒ 124800
# Q 349*308 T 107492 ☒ 124552
# Q 386*540 T 208440 ☒ 215440
# Q 945*14  T 13230  ☒ 14930
# Q 15*351  T 5265   ☒ 5775
# Q 256*766 T 196096 ☒ 215554
# Q 47*863  T 40561  ☒ 44441
#
# --------------------------------------------------
# Iteration 16
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 394us/step - loss: 1.3213 - acc: 0.4764 - val_loss: 1.3133 - val_acc: 0.4752
# Q 449*895 T 401855 ☒ 399685
# Q 973*195 T 189735 ☒ 199665
# Q 44*364  T 16016  ☒ 15774
# Q 623*517 T 322091 ☒ 331661
# Q 375*45  T 16875  ☒ 16175
# Q 97*33   T 3201   ☒ 3863
# Q 960*496 T 476160 ☒ 496660
# Q 563*107 T 60241  ☒ 76637
# Q 47*863  T 40561  ☒ 44463
# Q 82*200  T 16400  ☒ 14800
#
# --------------------------------------------------
# Iteration 17
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 412us/step - loss: 1.3060 - acc: 0.4814 - val_loss: 1.3019 - val_acc: 0.4790
# Q 92*490  T 45080  ☒ 42480
# Q 47*430  T 20210  ☒ 29830
# Q 578*248 T 143344 ☒ 123692
# Q 500*71  T 35500  ☒ 33500
# Q 240*380 T 91200  ☒ 88800
# Q 6*976   T 5856   ☒ 5662
# Q 506*741 T 374946 ☒ 326624
# Q 980*86  T 84280  ☒ 77840
# Q 194*30  T 5820   ☒ 5420
# Q 66*416  T 27456  ☒ 23424
#
# --------------------------------------------------
# Iteration 18
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 396us/step - loss: 1.2880 - acc: 0.4882 - val_loss: 1.2942 - val_acc: 0.4792
# Q 484*147 T 71148  ☒ 76622
# Q 654*0   T 0      ☑ 0
# Q 57*723  T 41211  ☒ 48571
# Q 899*4   T 3596   ☒ 3824
# Q 332*1   T 332    ☒ 484
# Q 43*303  T 13029  ☒ 13157
# Q 207*0   T 0      ☑ 0
# Q 93*341  T 31713  ☒ 38571
# Q 100*583 T 58300  ☒ 71700
# Q 840*485 T 407400 ☒ 385800
#
# --------------------------------------------------
# Iteration 19
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 405us/step - loss: 1.2700 - acc: 0.4961 - val_loss: 1.2887 - val_acc: 0.4821
# Q 930*14  T 13020  ☒ 12880
# Q 96*53   T 5088   ☒ 5264
# Q 175*3   T 525    ☒ 555
# Q 115*241 T 27715  ☒ 22055
# Q 699*116 T 81084  ☒ 80898
# Q 961*29  T 27869  ☒ 25893
# Q 70*151  T 10570  ☒ 10110
# Q 89*76   T 6764   ☒ 6666
# Q 778*48  T 37344  ☒ 38882
# Q 97*5    T 485    ☒ 555
#
# --------------------------------------------------
# Iteration 20
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 429us/step - loss: 1.2618 - acc: 0.4993 - val_loss: 1.2713 - val_acc: 0.4819
# Q 447*900 T 402300 ☒ 384700
# Q 939*72  T 67608  ☒ 73034
# Q 2*888   T 1776   ☒ 1798
# Q 86*92   T 7912   ☒ 7784
# Q 939*72  T 67608  ☒ 73034
# Q 541*580 T 313780 ☒ 314880
# Q 65*291  T 18915  ☒ 18925
# Q 308*16  T 4928   ☒ 4142
# Q 658*290 T 190820 ☒ 199920
# Q 453*449 T 203397 ☒ 299999
#
# --------------------------------------------------
# Iteration 21
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 405us/step - loss: 1.2444 - acc: 0.5072 - val_loss: 1.2517 - val_acc: 0.4980
# Q 383*94  T 36002  ☒ 38808
# Q 130*174 T 22620  ☒ 21120
# Q 839*836 T 701404 ☒ 638008
# Q 74*195  T 14430  ☒ 14890
# Q 776*52  T 40352  ☒ 48114
# Q 73*142  T 10366  ☒ 11002
# Q 266*42  T 11172  ☒ 11112
# Q 868*3   T 2604   ☒ 2584
# Q 916*467 T 427772 ☒ 438888
# Q 272*81  T 22032  ☒ 22558
#
# --------------------------------------------------
# Iteration 22
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 403us/step - loss: 1.2300 - acc: 0.5139 - val_loss: 1.2436 - val_acc: 0.4990
# Q 229*18  T 4122   ☒ 4668
# Q 4*898   T 3592   ☒ 3266
# Q 104*417 T 43368  ☒ 46648
# Q 835*52  T 43420  ☒ 49030
# Q 80*17   T 1360   ☒ 1240
# Q 668*64  T 42752  ☒ 40022
# Q 873*82  T 71586  ☒ 62666
# Q 628*99  T 62172  ☒ 66662
# Q 13*585  T 7605   ☒ 7625
# Q 755*41  T 30955  ☒ 31225
#
# --------------------------------------------------
# Iteration 23
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 411us/step - loss: 1.2203 - acc: 0.5169 - val_loss: 1.2322 - val_acc: 0.5018
# Q 52*118  T 6136   ☒ 6122
# Q 205*73  T 14965  ☒ 15075
# Q 895*64  T 57280  ☒ 53380
# Q 27*19   T 513    ☒ 491
# Q 422*940 T 396680 ☒ 386740
# Q 277*51  T 14127  ☒ 14427
# Q 621*950 T 589950 ☒ 564450
# Q 375*45  T 16875  ☒ 16275
# Q 51*868  T 44268  ☒ 44664
# Q 70*992  T 69440  ☒ 75560
#
# --------------------------------------------------
# Iteration 24
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 402us/step - loss: 1.2151 - acc: 0.5193 - val_loss: 1.2207 - val_acc: 0.5130
# Q 368*894 T 328992 ☒ 326622
# Q 728*505 T 367640 ☒ 351580
# Q 443*94  T 41642  ☒ 42622
# Q 554*18  T 9972   ☒ 9014
# Q 580*510 T 295800 ☒ 282200
# Q 192*628 T 120576 ☒ 126798
# Q 192*345 T 66240  ☒ 61780
# Q 706*137 T 96722  ☒ 10626
# Q 930*654 T 608220 ☒ 598420
# Q 50*606  T 30300  ☒ 31600
#
# --------------------------------------------------
# Iteration 25
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 405us/step - loss: 1.2000 - acc: 0.5236 - val_loss: 1.2115 - val_acc: 0.5124
# Q 26*307  T 7982   ☒ 8404
# Q 538*70  T 37660  ☒ 35220
# Q 873*82  T 71586  ☒ 65656
# Q 628*650 T 408200 ☒ 365300
# Q 31*95   T 2945   ☒ 3135
# Q 426*226 T 96276  ☒ 90814
# Q 423*921 T 389583 ☒ 341199
# Q 318*461 T 146598 ☒ 141468
# Q 591*218 T 128838 ☒ 131268
# Q 574*1   T 574    ☒ 684
#
# --------------------------------------------------
# Iteration 26
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 414us/step - loss: 1.1902 - acc: 0.5300 - val_loss: 1.1989 - val_acc: 0.5164
# Q 446*67  T 29882  ☒ 28222
# Q 281*39  T 10959  ☒ 11171
# Q 895*3   T 2685   ☒ 2575
# Q 108*927 T 100116 ☒ 90802
# Q 88*654  T 57552  ☒ 59262
# Q 261*74  T 19314  ☒ 19812
# Q 517*608 T 314336 ☒ 316222
# Q 280*461 T 129080 ☒ 128240
# Q 44*662  T 29128  ☒ 28224
# Q 777*29  T 22533  ☒ 22111
#
# --------------------------------------------------
# Iteration 27
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 400us/step - loss: 1.1820 - acc: 0.5299 - val_loss: 1.1924 - val_acc: 0.5253
# Q 339*3   T 1017   ☒ 101
# Q 555*3   T 1665   ☒ 1705
# Q 158*499 T 78842  ☒ 86008
# Q 85*307  T 26095  ☒ 25011
# Q 953*887 T 845311 ☒ 779277
# Q 538*7   T 3766   ☒ 3524
# Q 664*31  T 20584  ☒ 29494
# Q 173*988 T 170924 ☒ 175554
# Q 613*99  T 60687  ☒ 67547
# Q 940*598 T 562120 ☒ 531740
#
# --------------------------------------------------
# Iteration 28
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 415us/step - loss: 1.1709 - acc: 0.5375 - val_loss: 1.1901 - val_acc: 0.5170
# Q 170*986 T 167620 ☒ 166460
# Q 615*93  T 57195  ☒ 53675
# Q 335*30  T 10050  ☒ 10250
# Q 198*92  T 18216  ☒ 18366
# Q 719*23  T 16537  ☒ 17417
# Q 487*81  T 39447  ☒ 38639
# Q 452*524 T 236848 ☒ 232366
# Q 82*419  T 34358  ☒ 33664
# Q 97*33   T 3201   ☒ 3347
# Q 51*387  T 19737  ☒ 19017
#
# --------------------------------------------------
# Iteration 29
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 403us/step - loss: 1.1623 - acc: 0.5413 - val_loss: 1.1740 - val_acc: 0.5267
# Q 339*3   T 1017   ☒ 1011
# Q 995*555 T 552225 ☒ 531425
# Q 482*384 T 185088 ☒ 186368
# Q 975*404 T 393900 ☒ 388880
# Q 931*437 T 406847 ☒ 487749
# Q 17*723  T 12291  ☒ 12523
# Q 947*415 T 393005 ☒ 388825
# Q 579*9   T 5211   ☒ 5301
# Q 949*791 T 750659 ☒ 743021
# Q 649*936 T 607464 ☒ 623132
#
# --------------------------------------------------
# Iteration 30
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 404us/step - loss: 1.1519 - acc: 0.5454 - val_loss: 1.2111 - val_acc: 0.5013
# Q 18*94   T 1692   ☒ 1672
# Q 289*639 T 184671 ☒ 189219
# Q 201*7   T 1407   ☒ 1423
# Q 238*71  T 16898  ☒ 16622
# Q 433*33  T 14289  ☒ 14833
# Q 2*877   T 1754   ☒ 1862
# Q 379*535 T 202765 ☒ 190225
# Q 446*67  T 29882  ☒ 29482
# Q 37*351  T 12987  ☒ 12523
# Q 717*6   T 4302   ☒ 4248
#
# --------------------------------------------------
# Iteration 31
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 400us/step - loss: 1.1474 - acc: 0.5483 - val_loss: 1.1668 - val_acc: 0.5289
# Q 144*902 T 129888 ☒ 129712
# Q 88*196  T 17248  ☒ 17772
# Q 97*648  T 62856  ☒ 62076
# Q 140*78  T 10920  ☒ 11160
# Q 82*180  T 14760  ☒ 14720
# Q 961*18  T 17298  ☒ 16658
# Q 293*167 T 48931  ☒ 41011
# Q 389*605 T 235345 ☒ 235555
# Q 487*8   T 3896   ☒ 3904
# Q 84*74   T 6216   ☒ 5978
#
# --------------------------------------------------
# Iteration 32
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 397us/step - loss: 1.1353 - acc: 0.5541 - val_loss: 1.1549 - val_acc: 0.5364
# Q 334*100 T 33400  ☒ 34800
# Q 814*236 T 192104 ☒ 192366
# Q 226*752 T 169952 ☒ 175362
# Q 713*49  T 34937  ☒ 35239
# Q 42*505  T 21210  ☒ 21800
# Q 5*609   T 3045   ☒ 3055
# Q 132*787 T 103884 ☒ 101002
# Q 172*45  T 7740   ☒ 7900
# Q 419*871 T 364949 ☒ 362139
# Q 18*989  T 17802  ☒ 18606
#
# --------------------------------------------------
# Iteration 33
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 405us/step - loss: 1.1282 - acc: 0.5558 - val_loss: 1.1726 - val_acc: 0.5242
# Q 745*371 T 276395 ☒ 288075
# Q 26*838  T 21788  ☒ 21766
# Q 48*56   T 2688   ☒ 2678
# Q 19*742  T 14098  ☒ 12702
# Q 129*49  T 6321   ☒ 6877
# Q 401*931 T 373331 ☒ 367789
# Q 366*7   T 2562   ☒ 2594
# Q 477*383 T 182691 ☒ 187009
# Q 223*96  T 21408  ☒ 20408
# Q 7*277   T 1939   ☒ 1893
#
# --------------------------------------------------
# Iteration 34
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 400us/step - loss: 1.1274 - acc: 0.5544 - val_loss: 1.1707 - val_acc: 0.5253
# Q 41*186  T 7626   ☒ 7616
# Q 75*942  T 70650  ☒ 74690
# Q 527*15  T 7905   ☒ 7105
# Q 32*29   T 928    ☒ 9012
# Q 426*946 T 402996 ☒ 419714
# Q 204*849 T 173196 ☒ 179556
# Q 602*166 T 99932  ☒ 10116
# Q 341*100 T 34100  ☒ 33100
# Q 924*11  T 10164  ☒ 10168
# Q 26*307  T 7982   ☒ 8006
#
# --------------------------------------------------
# Iteration 35
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 403us/step - loss: 1.1213 - acc: 0.5569 - val_loss: 1.1423 - val_acc: 0.5374
# Q 409*902 T 368918 ☒ 366672
# Q 70*883  T 61810  ☒ 62230
# Q 26*828  T 21528  ☒ 21768
# Q 29*217  T 6293   ☒ 6007
# Q 98*85   T 8330   ☒ 7480
# Q 438*530 T 232140 ☒ 237760
# Q 616*26  T 16016  ☒ 15168
# Q 75*595  T 44625  ☒ 44775
# Q 93*696  T 64728  ☒ 62656
# Q 41*866  T 35506  ☒ 36264
#
# --------------------------------------------------
# Iteration 36
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 400us/step - loss: 1.1050 - acc: 0.5679 - val_loss: 1.1288 - val_acc: 0.5485
# Q 81*7    T 567    ☒ 557
# Q 82*419  T 34358  ☒ 35164
# Q 574*61  T 35014  ☒ 35124
# Q 949*18  T 17082  ☒ 17556
# Q 550*370 T 203500 ☒ 201500
# Q 585*628 T 367380 ☒ 363840
# Q 776*52  T 40352  ☒ 41052
# Q 61*552  T 33672  ☒ 32104
# Q 996*83  T 82668  ☒ 87002
# Q 256*766 T 196096 ☒ 190306
#
# --------------------------------------------------
# Iteration 37
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 406us/step - loss: 1.0984 - acc: 0.5692 - val_loss: 1.1326 - val_acc: 0.5455
# Q 60*794  T 47640  ☒ 45780
# Q 8*987   T 7896   ☒ 7138
# Q 295*169 T 49855  ☒ 56835
# Q 441*309 T 136269 ☒ 131389
# Q 931*236 T 219716 ☒ 221858
# Q 369*198 T 73062  ☒ 66078
# Q 895*64  T 57280  ☒ 56490
# Q 911*66  T 60126  ☒ 69668
# Q 413*857 T 353941 ☒ 367989
# Q 930*654 T 608220 ☒ 684440
#
# --------------------------------------------------
# Iteration 38
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 408us/step - loss: 1.0931 - acc: 0.5695 - val_loss: 1.1111 - val_acc: 0.5581
# Q 72*919  T 66168  ☒ 62666
# Q 707*95  T 67165  ☒ 69005
# Q 814*236 T 192104 ☒ 199326
# Q 996*83  T 82668  ☒ 84132
# Q 36*569  T 20484  ☒ 20656
# Q 194*601 T 116594 ☒ 116268
# Q 463*133 T 61579  ☒ 63081
# Q 87*201  T 17487  ☒ 17563
# Q 305*50  T 15250  ☒ 15550
# Q 92*490  T 45080  ☒ 44160
#
# --------------------------------------------------
# Iteration 39
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 415us/step - loss: 1.0859 - acc: 0.5738 - val_loss: 1.1157 - val_acc: 0.5492
# Q 55*66   T 3630   ☑ 3630
# Q 75*595  T 44625  ☒ 44675
# Q 79*598  T 47242  ☒ 47666
# Q 61*593  T 36173  ☒ 36299
# Q 14*622  T 8708   ☒ 9752
# Q 828*114 T 94392  ☒ 93122
# Q 99*368  T 36432  ☒ 36612
# Q 589*536 T 315704 ☒ 316258
# Q 38*512  T 19456  ☒ 19328
# Q 570*782 T 445740 ☒ 446180
#
# --------------------------------------------------
# Iteration 40
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 414us/step - loss: 1.0832 - acc: 0.5745 - val_loss: 1.1072 - val_acc: 0.5552
# Q 495*278 T 137610 ☒ 139490
# Q 300*387 T 116100 ☒ 115100
# Q 901*15  T 13515  ☒ 13505
# Q 32*29   T 928    ☒ 908
# Q 93*49   T 4557   ☒ 4631
# Q 630*59  T 37170  ☒ 36010
# Q 386*238 T 91868  ☒ 90008
# Q 680*675 T 459000 ☒ 455500
# Q 66*66   T 4356   ☒ 4432
# Q 32*445  T 14240  ☒ 14890
#
# --------------------------------------------------
# Iteration 41
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 417us/step - loss: 1.0697 - acc: 0.5836 - val_loss: 1.1270 - val_acc: 0.5510
# Q 71*101  T 7171   ☒ 7191
# Q 966*682 T 658812 ☒ 629968
# Q 9*568   T 5112   ☒ 5108
# Q 70*879  T 61530  ☒ 62530
# Q 1*341   T 341    ☒ 339
# Q 2*246   T 492    ☒ 466
# Q 439*44  T 19316  ☒ 19374
# Q 5*498   T 2490   ☑ 2490
# Q 261*74  T 19314  ☒ 19362
# Q 774*65  T 50310  ☒ 59590
#
# --------------------------------------------------
# Iteration 42
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 399us/step - loss: 1.0691 - acc: 0.5827 - val_loss: 1.0981 - val_acc: 0.5596
# Q 60*666  T 39960  ☒ 38440
# Q 93*770  T 71610  ☒ 77270
# Q 68*115  T 7820   ☒ 7320
# Q 87*201  T 17487  ☒ 17147
# Q 902*646 T 582692 ☒ 564744
# Q 61*60   T 3660   ☒ 3640
# Q 36*259  T 9324   ☒ 9004
# Q 769*44  T 33836  ☒ 33432
# Q 59*87   T 5133   ☒ 5239
# Q 852*19  T 16188  ☒ 15148
#
# --------------------------------------------------
# Iteration 43
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 398us/step - loss: 1.0572 - acc: 0.5887 - val_loss: 1.0983 - val_acc: 0.5563
# Q 455*104 T 47320  ☒ 46610
# Q 752*4   T 3008   ☒ 3052
# Q 61*805  T 49105  ☒ 49555
# Q 525*13  T 6825   ☒ 7125
# Q 118*993 T 117174 ☒ 116602
# Q 71*275  T 19525  ☒ 19225
# Q 58*10   T 580    ☑ 580
# Q 765*772 T 590580 ☒ 692220
# Q 41*513  T 21033  ☒ 20193
# Q 77*965  T 74305  ☒ 76255
#
# --------------------------------------------------
# Iteration 44
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 400us/step - loss: 1.0497 - acc: 0.5946 - val_loss: 1.0853 - val_acc: 0.5681
# Q 868*3   T 2604   ☒ 2564
# Q 61*552  T 33672  ☒ 32152
# Q 36*60   T 2160   ☑ 2160
# Q 3*884   T 2652   ☒ 2664
# Q 507*318 T 161226 ☒ 155516
# Q 520*69  T 35880  ☒ 35060
# Q 892*43  T 38356  ☒ 37676
# Q 296*734 T 217264 ☒ 212554
# Q 198*38  T 7524   ☒ 7574
# Q 124*925 T 114700 ☒ 118000
#
# --------------------------------------------------
# Iteration 45
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 399us/step - loss: 1.0391 - acc: 0.6000 - val_loss: 1.0727 - val_acc: 0.5809
# Q 943*94  T 88642  ☒ 89936
# Q 231*407 T 94017  ☒ 88839
# Q 15*335  T 5025   ☒ 5475
# Q 128*8   T 1024   ☒ 904
# Q 63*203  T 12789  ☒ 12569
# Q 319*19  T 6061   ☒ 5889
# Q 314*66  T 20724  ☒ 20324
# Q 143*295 T 42185  ☒ 48985
# Q 71*685  T 48635  ☒ 49155
# Q 98*732  T 71736  ☒ 76596
#
# --------------------------------------------------
# Iteration 46
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 395us/step - loss: 1.0247 - acc: 0.6096 - val_loss: 1.0468 - val_acc: 0.5939
# Q 305*50  T 15250  ☒ 15750
# Q 80*17   T 1360   ☒ 1320
# Q 46*657  T 30222  ☒ 30482
# Q 460*20  T 9200   ☒ 8400
# Q 384*74  T 28416  ☒ 28776
# Q 803*77  T 61831  ☒ 61137
# Q 19*623  T 11837  ☒ 11539
# Q 491*826 T 405566 ☒ 409186
# Q 27*931  T 25137  ☒ 24017
# Q 550*729 T 400950 ☒ 498850
#
# --------------------------------------------------
# Iteration 47
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 398us/step - loss: 1.0109 - acc: 0.6171 - val_loss: 1.0400 - val_acc: 0.6003
# Q 115*241 T 27715  ☒ 21895
# Q 717*38  T 27246  ☒ 27222
# Q 96*641  T 61536  ☒ 61236
# Q 148*726 T 107448 ☒ 108288
# Q 375*45  T 16875  ☒ 17275
# Q 595*11  T 6545   ☒ 6585
# Q 964*78  T 75192  ☒ 71372
# Q 19*742  T 14098  ☒ 14828
# Q 524*3   T 1572   ☒ 1578
# Q 934*953 T 890102 ☒ 876272
#
# --------------------------------------------------
# Iteration 48
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 400us/step - loss: 1.0056 - acc: 0.6213 - val_loss: 1.0249 - val_acc: 0.6125
# Q 453*28  T 12684  ☒ 12724
# Q 204*849 T 173196 ☒ 172698
# Q 56*295  T 16520  ☒ 16950
# Q 784*575 T 450800 ☒ 435520
# Q 246*85  T 20910  ☒ 20330
# Q 962*760 T 731120 ☒ 768520
# Q 310*34  T 10540  ☒ 10180
# Q 733*885 T 648705 ☒ 640105
# Q 84*992  T 83328  ☒ 86736
# Q 74*195  T 14430  ☒ 14790
#
# --------------------------------------------------
# Iteration 49
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 400us/step - loss: 0.9776 - acc: 0.6381 - val_loss: 1.0198 - val_acc: 0.6104
# Q 613*99  T 60687  ☒ 59351
# Q 21*616  T 12936  ☒ 12336
# Q 0*112   T 0      ☑ 0
# Q 463*133 T 61579  ☒ 63079
# Q 405*961 T 389205 ☒ 397975
# Q 198*92  T 18216  ☒ 18456
# Q 439*51  T 22389  ☒ 22819
# Q 776*52  T 40352  ☒ 41152
# Q 69*169  T 11661  ☒ 11401
# Q 975*404 T 393900 ☒ 405800
#
# --------------------------------------------------
# Iteration 50
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 394us/step - loss: 0.9628 - acc: 0.6439 - val_loss: 1.0124 - val_acc: 0.6149
# Q 112*924 T 103488 ☒ 102288
# Q 507*3   T 1521   ☒ 1513
# Q 27*918  T 24786  ☒ 24436
# Q 952*18  T 17136  ☒ 16566
# Q 25*401  T 10025  ☑ 10025
# Q 306*864 T 264384 ☒ 253584
# Q 90*968  T 87120  ☒ 81140
# Q 17*55   T 935    ☒ 995
# Q 60*661  T 39660  ☒ 30160
# Q 1*341   T 341    ☒ 333
#
# --------------------------------------------------
# Iteration 51
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 402us/step - loss: 0.9543 - acc: 0.6469 - val_loss: 1.0229 - val_acc: 0.6081
# Q 77*960  T 73920  ☒ 78870
# Q 972*399 T 387828 ☒ 386588
# Q 90*906  T 81540  ☒ 74840
# Q 663*11  T 7293   ☑ 7293
# Q 852*98  T 83496  ☒ 71976
# Q 28*419  T 11732  ☒ 11352
# Q 20*752  T 15040  ☒ 14820
# Q 51*699  T 35649  ☒ 35389
# Q 623*517 T 322091 ☒ 311579
# Q 17*430  T 7310   ☒ 7390
#
# --------------------------------------------------
# Iteration 52
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 396us/step - loss: 0.9313 - acc: 0.6587 - val_loss: 0.9652 - val_acc: 0.6312
# Q 71*739  T 52469  ☒ 51369
# Q 867*67  T 58089  ☒ 55743
# Q 971*8   T 7768   ☒ 7588
# Q 725*93  T 67425  ☒ 69925
# Q 670*16  T 10720  ☒ 10120
# Q 283*983 T 278189 ☒ 276119
# Q 761*93  T 70773  ☒ 69343
# Q 846*712 T 602352 ☒ 598432
# Q 776*30  T 23280  ☒ 23360
# Q 140*52  T 7280   ☒ 7380
#
# --------------------------------------------------
# Iteration 53
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 396us/step - loss: 0.9130 - acc: 0.6667 - val_loss: 0.9890 - val_acc: 0.6157
# Q 88*532  T 46816  ☒ 47916
# Q 93*696  T 64728  ☒ 62758
# Q 64*617  T 39488  ☒ 39418
# Q 296*734 T 217264 ☒ 212384
# Q 34*529  T 17986  ☒ 17966
# Q 52*712  T 37024  ☒ 36084
# Q 974*19  T 18506  ☒ 18636
# Q 953*887 T 845311 ☒ 899171
# Q 13*262  T 3406   ☒ 3446
# Q 884*700 T 618800 ☒ 621600
#
# --------------------------------------------------
# Iteration 54
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 396us/step - loss: 0.9008 - acc: 0.6711 - val_loss: 0.9458 - val_acc: 0.6418
# Q 87*490  T 42630  ☒ 42690
# Q 550*526 T 289300 ☒ 287300
# Q 41*571  T 23411  ☒ 23461
# Q 839*836 T 701404 ☒ 673754
# Q 734*83  T 60922  ☒ 61412
# Q 820*458 T 375560 ☒ 376120
# Q 130*174 T 22620  ☒ 12720
# Q 420*0   T 0      ☑ 0
# Q 585*2   T 1170   ☒ 1180
# Q 413*66  T 27258  ☒ 27778
#
# --------------------------------------------------
# Iteration 55
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 396us/step - loss: 0.8951 - acc: 0.6711 - val_loss: 0.9360 - val_acc: 0.6506
# Q 0*319   T 0      ☑ 0
# Q 761*781 T 594341 ☒ 579291
# Q 5*400   T 2000   ☒ 200
# Q 460*92  T 42320  ☒ 42120
# Q 563*346 T 194798 ☒ 199318
# Q 132*787 T 103884 ☒ 108004
# Q 553*796 T 440188 ☒ 433178
# Q 55*66   T 3630   ☒ 3670
# Q 285*66  T 18810  ☒ 18370
# Q 90*924  T 83160  ☒ 81720
#
# --------------------------------------------------
# Iteration 56
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 399us/step - loss: 0.8730 - acc: 0.6815 - val_loss: 0.9278 - val_acc: 0.6512
# Q 63*45   T 2835   ☒ 2815
# Q 215*87  T 18705  ☒ 18965
# Q 48*345  T 16560  ☒ 16280
# Q 630*59  T 37170  ☒ 36070
# Q 582*96  T 55872  ☒ 55492
# Q 10*168  T 1680   ☒ 2440
# Q 388*472 T 183136 ☒ 174916
# Q 734*83  T 60922  ☒ 62452
# Q 99*368  T 36432  ☒ 36112
# Q 431*779 T 335749 ☒ 347769
#
# --------------------------------------------------
# Iteration 57
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 401us/step - loss: 0.8619 - acc: 0.6850 - val_loss: 0.9177 - val_acc: 0.6524
# Q 45*559  T 25155  ☒ 24905
# Q 174*763 T 132762 ☒ 126852
# Q 339*43  T 14577  ☒ 14117
# Q 164*27  T 4428   ☒ 4178
# Q 383*49  T 18767  ☒ 18687
# Q 336*330 T 110880 ☒ 115280
# Q 74*195  T 14430  ☒ 14590
# Q 502*73  T 36646  ☒ 36286
# Q 56*855  T 47880  ☒ 47690
# Q 996*818 T 814728 ☒ 767704
#
# --------------------------------------------------
# Iteration 58
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 397us/step - loss: 0.8717 - acc: 0.6767 - val_loss: 0.9442 - val_acc: 0.6365
# Q 56*629  T 35224  ☒ 33464
# Q 706*48  T 33888  ☒ 33468
# Q 459*689 T 316251 ☒ 314961
# Q 458*477 T 218466 ☒ 212686
# Q 495*480 T 237600 ☒ 234400
# Q 77*526  T 40502  ☒ 40232
# Q 469*75  T 35175  ☒ 34485
# Q 2*920   T 1840   ☑ 1840
# Q 650*78  T 50700  ☒ 49300
# Q 602*166 T 99932  ☒ 90134
#
# --------------------------------------------------
# Iteration 59
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 401us/step - loss: 0.8556 - acc: 0.6843 - val_loss: 0.9209 - val_acc: 0.6500
# Q 170*986 T 167620 ☒ 166420
# Q 477*383 T 182691 ☒ 187711
# Q 297*11  T 3267   ☒ 3847
# Q 13*585  T 7605   ☒ 7635
# Q 97*34   T 3298   ☒ 3348
# Q 0*385   T 0      ☑ 0
# Q 891*9   T 8019   ☒ 8639
# Q 593*18  T 10674  ☑ 10674
# Q 258*578 T 149124 ☒ 156644
# Q 76*71   T 5396   ☒ 5436
#
# --------------------------------------------------
# Iteration 60
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 397us/step - loss: 0.8525 - acc: 0.6834 - val_loss: 0.9440 - val_acc: 0.6377
# Q 486*42  T 20412  ☒ 20592
# Q 288*823 T 237024 ☒ 231564
# Q 949*791 T 750659 ☒ 762229
# Q 733*660 T 483780 ☒ 492780
# Q 359*166 T 59594  ☒ 52674
# Q 713*225 T 160425 ☒ 155575
# Q 158*481 T 75998  ☒ 76618
# Q 78*29   T 2262   ☒ 2292
# Q 80*17   T 1360   ☑ 1360
# Q 75*899  T 67425  ☒ 79125
#
# --------------------------------------------------
# Iteration 61
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 401us/step - loss: 0.8410 - acc: 0.6897 - val_loss: 0.9051 - val_acc: 0.6527
# Q 394*368 T 144992 ☒ 140692
# Q 229*69  T 15801  ☒ 15211
# Q 302*302 T 91204  ☒ 80004
# Q 840*56  T 47040  ☑ 47040
# Q 9*690   T 6210   ☒ 6110
# Q 317*207 T 65619  ☒ 67799
# Q 192*55  T 10560  ☒ 10830
# Q 555*3   T 1665   ☒ 1685
# Q 27*585  T 15795  ☒ 15065
# Q 69*245  T 16905  ☒ 16105
#
# --------------------------------------------------
# Iteration 62
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 396us/step - loss: 0.8361 - acc: 0.6896 - val_loss: 0.8852 - val_acc: 0.6638
# Q 71*101  T 7171   ☒ 7001
# Q 5*900   T 4500   ☑ 4500
# Q 88*793  T 69784  ☒ 68004
# Q 77*960  T 73920  ☒ 73820
# Q 881*84  T 74004  ☒ 71984
# Q 17*469  T 7973   ☒ 7403
# Q 3*884   T 2652   ☒ 2632
# Q 18*403  T 7254   ☒ 7014
# Q 112*70  T 7840   ☒ 7340
# Q 208*81  T 16848  ☒ 16368
#
# --------------------------------------------------
# Iteration 63
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 393us/step - loss: 0.8244 - acc: 0.6967 - val_loss: 0.8856 - val_acc: 0.6646
# Q 90*298  T 26820  ☒ 26720
# Q 128*742 T 94976  ☒ 96228
# Q 687*53  T 36411  ☒ 36271
# Q 6*43    T 258    ☒ 268
# Q 162*94  T 15228  ☒ 15248
# Q 750*83  T 62250  ☒ 62550
# Q 58*730  T 42340  ☒ 42140
# Q 51*521  T 26571  ☒ 26011
# Q 995*998 T 993010 ☒ 800230
# Q 172*45  T 7740   ☒ 7320
#
# --------------------------------------------------
# Iteration 64
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 390us/step - loss: 0.8214 - acc: 0.6971 - val_loss: 0.8863 - val_acc: 0.6683
# Q 86*845  T 72670  ☒ 72270
# Q 51*716  T 36516  ☒ 36666
# Q 207*603 T 124821 ☒ 126281
# Q 946*36  T 34056  ☒ 34746
# Q 839*581 T 487459 ☒ 495909
# Q 194*30  T 5820   ☒ 5920
# Q 442*596 T 263432 ☒ 266052
# Q 327*493 T 161211 ☒ 167231
# Q 98*903  T 88494  ☒ 81274
# Q 211*396 T 83556  ☒ 88556
#
# --------------------------------------------------
# Iteration 65
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 393us/step - loss: 0.8124 - acc: 0.7017 - val_loss: 0.8696 - val_acc: 0.6769
# Q 123*628 T 77244  ☒ 74504
# Q 477*19  T 9063   ☒ 9453
# Q 98*541  T 53018  ☒ 52878
# Q 233*27  T 6291   ☒ 6511
# Q 70*185  T 12950  ☒ 12650
# Q 379*535 T 202765 ☒ 201005
# Q 63*405  T 25515  ☒ 25065
# Q 604*7   T 4228   ☑ 4228
# Q 48*194  T 9312   ☒ 9952
# Q 846*72  T 60912  ☒ 61032
#
# --------------------------------------------------
# Iteration 66
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 390us/step - loss: 0.8052 - acc: 0.7040 - val_loss: 0.8604 - val_acc: 0.6731
# Q 70*151  T 10570  ☒ 10110
# Q 280*461 T 129080 ☒ 126880
# Q 339*3   T 1017   ☒ 1019
# Q 460*20  T 9200   ☒ 8400
# Q 364*438 T 159432 ☒ 152552
# Q 69*651  T 44919  ☒ 44579
# Q 419*747 T 312993 ☒ 311733
# Q 579*9   T 5211   ☒ 5391
# Q 845*712 T 601640 ☒ 615840
# Q 66*16   T 1056   ☒ 1016
#
# --------------------------------------------------
# Iteration 67
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 396us/step - loss: 0.8119 - acc: 0.6976 - val_loss: 0.8744 - val_acc: 0.6612
# Q 774*65  T 50310  ☒ 50070
# Q 524*6   T 3144   ☒ 3164
# Q 78*660  T 51480  ☒ 50280
# Q 11*42   T 462    ☒ 402
# Q 67*900  T 60300  ☒ 59100
# Q 969*106 T 102714 ☒ 10816
# Q 264*17  T 4488   ☒ 4668
# Q 155*693 T 107415 ☒ 108605
# Q 724*45  T 32580  ☒ 33240
# Q 510*27  T 13770  ☒ 13170
#
# --------------------------------------------------
# Iteration 68
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 392us/step - loss: 0.7973 - acc: 0.7057 - val_loss: 0.9326 - val_acc: 0.6402
# Q 914*616 T 563024 ☒ 551484
# Q 14*236  T 3304   ☒ 3844
# Q 654*44  T 28776  ☒ 28836
# Q 1*647   T 647    ☒ 627
# Q 28*965  T 27020  ☒ 26420
# Q 68*613  T 41684  ☒ 41324
# Q 331*846 T 280026 ☒ 273116
# Q 880*73  T 64240  ☒ 63640
# Q 550*370 T 203500 ☒ 201500
# Q 211*215 T 45365  ☒ 41585
#
# --------------------------------------------------
# Iteration 69
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 395us/step - loss: 0.7938 - acc: 0.7061 - val_loss: 0.8550 - val_acc: 0.6759
# Q 500*71  T 35500  ☒ 34500
# Q 690*7   T 4830   ☒ 4810
# Q 463*133 T 61579  ☒ 62179
# Q 678*34  T 23052  ☒ 23092
# Q 18*550  T 9900   ☒ 1060
# Q 48*113  T 5424   ☒ 5364
# Q 82*200  T 16400  ☑ 16400
# Q 917*911 T 835387 ☒ 861267
# Q 911*66  T 60126  ☒ 60476
# Q 409*902 T 368918 ☒ 368968
#
# --------------------------------------------------
# Iteration 70
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 385us/step - loss: 0.7921 - acc: 0.7041 - val_loss: 0.8486 - val_acc: 0.6743
# Q 339*9   T 3051   ☑ 3051
# Q 550*4   T 2200   ☑ 2200
# Q 668*64  T 42752  ☒ 42512
# Q 352*764 T 268928 ☒ 266528
# Q 49*985  T 48265  ☒ 48405
# Q 247*55  T 13585  ☒ 13005
# Q 966*492 T 475272 ☒ 480452
# Q 727*677 T 492179 ☒ 591999
# Q 733*433 T 317389 ☒ 311449
# Q 89*843  T 75027  ☒ 76647
#
# --------------------------------------------------
# Iteration 71
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 392us/step - loss: 0.7890 - acc: 0.7065 - val_loss: 0.8807 - val_acc: 0.6661
# Q 190*106 T 20140  ☒ 22740
# Q 45*372  T 16740  ☒ 16920
# Q 41*513  T 21033  ☒ 21313
# Q 41*513  T 21033  ☒ 21313
# Q 592*718 T 425056 ☒ 425596
# Q 580*870 T 504600 ☒ 402600
# Q 66*568  T 37488  ☒ 36508
# Q 100*583 T 58300  ☒ 64900
# Q 852*98  T 83496  ☒ 89696
# Q 616*26  T 16016  ☒ 16236
#
# --------------------------------------------------
# Iteration 72
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 393us/step - loss: 0.7790 - acc: 0.7124 - val_loss: 0.8473 - val_acc: 0.6793
# Q 18*403  T 7254   ☒ 7614
# Q 922*439 T 404758 ☒ 403448
# Q 810*984 T 797040 ☒ 866840
# Q 22*16   T 352    ☑ 352
# Q 117*735 T 85995  ☒ 86805
# Q 82*663  T 54366  ☒ 54906
# Q 755*41  T 30955  ☒ 30555
# Q 815*874 T 712310 ☒ 793490
# Q 5*428   T 2140   ☒ 2160
# Q 68*613  T 41684  ☒ 42624
#
# --------------------------------------------------
# Iteration 73
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 389us/step - loss: 0.7702 - acc: 0.7148 - val_loss: 0.8776 - val_acc: 0.6554
# Q 652*683 T 445316 ☒ 430446
# Q 507*620 T 314340 ☒ 302840
# Q 72*545  T 39240  ☒ 39840
# Q 8*204   T 1632   ☒ 1612
# Q 65*990  T 64350  ☒ 62550
# Q 310*34  T 10540  ☒ 10140
# Q 26*480  T 12480  ☒ 12080
# Q 587*383 T 224821 ☒ 226621
# Q 10*48   T 480    ☒ 440
# Q 66*16   T 1056   ☒ 1016
#
# --------------------------------------------------
# Iteration 74
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 387us/step - loss: 0.7665 - acc: 0.7158 - val_loss: 0.8361 - val_acc: 0.6793
# Q 826*300 T 247800 ☒ 244800
# Q 85*21   T 1785   ☒ 1855
# Q 471*317 T 149307 ☒ 154227
# Q 76*822  T 62472  ☒ 61032
# Q 232*87  T 20184  ☒ 20644
# Q 60*661  T 39660  ☒ 30260
# Q 18*94   T 1692   ☒ 1672
# Q 66*66   T 4356   ☒ 4316
# Q 623*380 T 236740 ☒ 232340
# Q 233*371 T 86443  ☒ 82523
#
# --------------------------------------------------
# Iteration 75
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 393us/step - loss: 0.7616 - acc: 0.7181 - val_loss: 0.8728 - val_acc: 0.6600
# Q 620*4   T 2480   ☒ 2580
# Q 210*970 T 203700 ☑ 203700
# Q 1*256   T 256    ☒ 270
# Q 902*678 T 611556 ☒ 616456
# Q 23*20   T 460    ☒ 480
# Q 378*43  T 16254  ☒ 16294
# Q 225*18  T 4050   ☒ 4850
# Q 139*545 T 75755  ☒ 76145
# Q 49*398  T 19502  ☒ 19942
# Q 39*317  T 12363  ☒ 12523
#
# --------------------------------------------------
# Iteration 76
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 393us/step - loss: 0.7651 - acc: 0.7137 - val_loss: 0.8754 - val_acc: 0.6620
# Q 316*475 T 150100 ☒ 155570
# Q 482*880 T 424160 ☒ 433160
# Q 319*400 T 127600 ☒ 127200
# Q 593*18  T 10674  ☑ 10674
# Q 429*993 T 425997 ☒ 427777
# Q 947*43  T 40721  ☒ 41201
# Q 52*819  T 42588  ☒ 43448
# Q 48*320  T 15360  ☒ 15160
# Q 705*480 T 338400 ☒ 344200
# Q 810*984 T 797040 ☒ 886940
#
# --------------------------------------------------
# Iteration 77
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 387us/step - loss: 0.7608 - acc: 0.7159 - val_loss: 0.8435 - val_acc: 0.6792
# Q 112*924 T 103488 ☒ 101228
# Q 826*300 T 247800 ☑ 247800
# Q 648*895 T 579960 ☒ 577160
# Q 331*846 T 280026 ☒ 281166
# Q 400*76  T 30400  ☑ 30400
# Q 813*33  T 26829  ☒ 26029
# Q 61*816  T 49776  ☒ 49726
# Q 81*91   T 7371   ☒ 7791
# Q 497*808 T 401576 ☒ 409996
# Q 123*29  T 3567   ☒ 3887
#
# --------------------------------------------------
# Iteration 78
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 390us/step - loss: 0.7521 - acc: 0.7208 - val_loss: 0.8351 - val_acc: 0.6777
# Q 229*33  T 7557   ☒ 7357
# Q 217*221 T 47957  ☒ 45777
# Q 9*308   T 2772   ☒ 2812
# Q 767*5   T 3835   ☒ 3815
# Q 3*645   T 1935   ☒ 1995
# Q 583*5   T 2915   ☒ 2815
# Q 725*23  T 16675  ☒ 16925
# Q 42*82   T 3444   ☑ 3444
# Q 315*90  T 28350  ☒ 28050
# Q 278*703 T 195434 ☒ 196614
#
# --------------------------------------------------
# Iteration 79
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 391us/step - loss: 0.7407 - acc: 0.7259 - val_loss: 0.8272 - val_acc: 0.6833
# Q 8*805   T 6440   ☒ 6220
# Q 155*17  T 2635   ☒ 2555
# Q 388*472 T 183136 ☒ 186816
# Q 676*669 T 452244 ☒ 446484
# Q 51*387  T 19737  ☒ 19717
# Q 27*678  T 18306  ☒ 18666
# Q 500*54  T 27000  ☑ 27000
# Q 155*17  T 2635   ☒ 2555
# Q 891*9   T 8019   ☒ 8739
# Q 639*633 T 404487 ☒ 404667
#
# --------------------------------------------------
# Iteration 80
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 386us/step - loss: 0.7480 - acc: 0.7214 - val_loss: 0.8444 - val_acc: 0.6736
# Q 924*21  T 19404  ☒ 19984
# Q 987*898 T 886326 ☒ 892276
# Q 515*895 T 460925 ☒ 464725
# Q 979*360 T 352440 ☒ 356840
# Q 325*148 T 48100  ☒ 40900
# Q 742*76  T 56392  ☒ 56272
# Q 0*0     T 0      ☑ 0
# Q 482*880 T 424160 ☒ 426760
# Q 690*6   T 4140   ☑ 4140
# Q 17*55   T 935    ☒ 995
#
# --------------------------------------------------
# Iteration 81
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 386us/step - loss: 0.7544 - acc: 0.7175 - val_loss: 0.8517 - val_acc: 0.6723
# Q 952*554 T 527408 ☒ 537928
# Q 1*953   T 953    ☒ 993
# Q 904*389 T 351656 ☒ 357896
# Q 639*633 T 404487 ☒ 304007
# Q 276*82  T 22632  ☒ 22072
# Q 135*77  T 10395  ☒ 10305
# Q 9*650   T 5850   ☒ 5750
# Q 65*855  T 55575  ☒ 56125
# Q 1*662   T 662    ☒ 602
# Q 949*342 T 324558 ☒ 327748
#
# --------------------------------------------------
# Iteration 82
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 387us/step - loss: 0.7351 - acc: 0.7263 - val_loss: 0.8364 - val_acc: 0.6744
# Q 85*307  T 26095  ☒ 26995
# Q 923*135 T 124605 ☒ 121995
# Q 409*5   T 2045   ☒ 2015
# Q 594*766 T 455004 ☒ 450784
# Q 95*386  T 36670  ☒ 37810
# Q 48*886  T 42528  ☒ 42108
# Q 902*646 T 582692 ☒ 587492
# Q 302*244 T 73688  ☒ 78688
# Q 15*11   T 165    ☒ 155
# Q 621*83  T 51543  ☒ 52903
#
# --------------------------------------------------
# Iteration 83
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 390us/step - loss: 0.7270 - acc: 0.7307 - val_loss: 0.8448 - val_acc: 0.6759
# Q 486*6   T 2916   ☒ 2936
# Q 98*267  T 26166  ☒ 26906
# Q 194*30  T 5820   ☒ 5420
# Q 960*496 T 476160 ☒ 471360
# Q 516*65  T 33540  ☒ 34280
# Q 86*100  T 8600   ☑ 8600
# Q 901*90  T 81090  ☒ 87690
# Q 797*56  T 44632  ☒ 44072
# Q 59*87   T 5133   ☒ 5153
# Q 342*925 T 316350 ☒ 321850
#
# --------------------------------------------------
# Iteration 84
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 464us/step - loss: 0.7387 - acc: 0.7244 - val_loss: 0.8149 - val_acc: 0.6878
# Q 706*137 T 96722  ☒ 97122
# Q 417*8   T 3336   ☑ 3336
# Q 69*169  T 11661  ☒ 11461
# Q 426*226 T 96276  ☒ 97736
# Q 49*985  T 48265  ☒ 48115
# Q 753*29  T 21837  ☒ 21137
# Q 514*494 T 253916 ☒ 253836
# Q 580*302 T 175160 ☒ 174660
# Q 507*620 T 314340 ☒ 312340
# Q 481*77  T 37037  ☒ 37197
#
# --------------------------------------------------
# Iteration 85
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 432us/step - loss: 0.7165 - acc: 0.7341 - val_loss: 0.8245 - val_acc: 0.6856
# Q 36*889  T 32004  ☒ 32424
# Q 358*5   T 1790   ☒ 1830
# Q 962*760 T 731120 ☒ 734920
# Q 679*188 T 127652 ☒ 124652
# Q 21*842  T 17682  ☒ 17992
# Q 379*535 T 202765 ☒ 201005
# Q 659*77  T 50743  ☒ 50083
# Q 937*7   T 6559   ☒ 6599
# Q 709*141 T 99969  ☒ 102209
# Q 84*253  T 21252  ☒ 20712
#
# --------------------------------------------------
# Iteration 86
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 393us/step - loss: 0.7149 - acc: 0.7340 - val_loss: 0.8707 - val_acc: 0.6617
# Q 780*22  T 17160  ☒ 16160
# Q 383*49  T 18767  ☒ 18807
# Q 333*19  T 6327   ☒ 5287
# Q 14*870  T 12180  ☒ 12880
# Q 689*513 T 353457 ☒ 347577
# Q 16*611  T 9776   ☒ 9006
# Q 596*907 T 540572 ☒ 533782
# Q 46*577  T 26542  ☒ 26272
# Q 680*675 T 459000 ☒ 460600
# Q 605*32  T 19360  ☒ 19060
#
# --------------------------------------------------
# Iteration 87
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 383us/step - loss: 0.7227 - acc: 0.7300 - val_loss: 0.8371 - val_acc: 0.6757
# Q 82*616  T 50512  ☒ 50492
# Q 9*308   T 2772   ☒ 2832
# Q 33*698  T 23034  ☒ 23854
# Q 83*368  T 30544  ☒ 30524
# Q 857*352 T 301664 ☒ 306974
# Q 95*600  T 57000  ☑ 57000
# Q 319*21  T 6699   ☒ 6999
# Q 106*679 T 71974  ☒ 64494
# Q 25*50   T 1250   ☑ 1250
# Q 956*521 T 498076 ☒ 493936
#
# --------------------------------------------------
# Iteration 88
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 377us/step - loss: 0.7199 - acc: 0.7311 - val_loss: 0.8216 - val_acc: 0.6847
# Q 408*42  T 17136  ☒ 17496
# Q 555*986 T 547230 ☒ 547490
# Q 952*18  T 17136  ☒ 16476
# Q 192*303 T 58176  ☒ 54286
# Q 371*82  T 30422  ☑ 30422
# Q 995*998 T 993010 ☒ 960230
# Q 949*28  T 26572  ☒ 26352
# Q 546*805 T 439530 ☒ 437430
# Q 460*92  T 42320  ☒ 42520
# Q 381*959 T 365379 ☒ 363919
#
# --------------------------------------------------
# Iteration 89
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 381us/step - loss: 0.7131 - acc: 0.7340 - val_loss: 0.8306 - val_acc: 0.6792
# Q 94*25   T 2350   ☑ 2350
# Q 230*38  T 8740   ☒ 8840
# Q 453*449 T 203397 ☒ 200617
# Q 866*3   T 2598   ☒ 2678
# Q 577*23  T 13271  ☒ 13111
# Q 19*719  T 13661  ☒ 13561
# Q 934*17  T 15878  ☒ 15088
# Q 1*125   T 125    ☑ 125
# Q 820*458 T 375560 ☒ 376560
# Q 15*335  T 5025   ☒ 5225
#
# --------------------------------------------------
# Iteration 90
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 388us/step - loss: 0.7075 - acc: 0.7370 - val_loss: 0.8350 - val_acc: 0.6795
# Q 2*842   T 1684   ☑ 1684
# Q 13*25   T 325    ☒ 375
# Q 507*327 T 165789 ☒ 160099
# Q 778*34  T 26452  ☒ 26632
# Q 713*38  T 27094  ☒ 27254
# Q 358*5   T 1790   ☒ 1830
# Q 9*737   T 6633   ☒ 6583
# Q 915*493 T 451095 ☒ 449285
# Q 393*23  T 9039   ☒ 9959
# Q 36*569  T 20484  ☒ 20564
#
# --------------------------------------------------
# Iteration 91
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 385us/step - loss: 0.7040 - acc: 0.7379 - val_loss: 0.8975 - val_acc: 0.6554
# Q 130*902 T 117260 ☒ 116260
# Q 86*949  T 81614  ☒ 86694
# Q 67*498  T 33366  ☒ 33206
# Q 520*69  T 35880  ☒ 35280
# Q 621*950 T 589950 ☒ 575550
# Q 82*404  T 33128  ☒ 33468
# Q 118*816 T 96288  ☒ 90508
# Q 750*83  T 62250  ☑ 62250
# Q 767*5   T 3835   ☒ 3715
# Q 923*827 T 763321 ☒ 745501
#
# --------------------------------------------------
# Iteration 92
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 380us/step - loss: 0.7084 - acc: 0.7355 - val_loss: 0.8260 - val_acc: 0.6823
# Q 3*736   T 2208   ☒ 2248
# Q 13*748  T 9724   ☒ 9762
# Q 638*204 T 130152 ☒ 139392
# Q 229*293 T 67097  ☒ 74917
# Q 266*51  T 13566  ☒ 13246
# Q 29*343  T 9947   ☒ 10027
# Q 86*92   T 7912   ☒ 7072
# Q 968*47  T 45496  ☒ 45036
# Q 6*946   T 5676   ☒ 5716
# Q 78*29   T 2262   ☒ 2202
#
# --------------------------------------------------
# Iteration 93
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 393us/step - loss: 0.6992 - acc: 0.7405 - val_loss: 0.8554 - val_acc: 0.6731
# Q 928*115 T 106720 ☒ 108540
# Q 150*804 T 120600 ☒ 122600
# Q 299*939 T 280761 ☒ 278881
# Q 56*295  T 16520  ☒ 16920
# Q 860*4   T 3440   ☑ 3440
# Q 430*85  T 36550  ☒ 36150
# Q 6*946   T 5676   ☒ 5716
# Q 594*766 T 455004 ☒ 450424
# Q 266*42  T 11172  ☒ 11412
# Q 728*601 T 437528 ☒ 448828
#
# --------------------------------------------------
# Iteration 94
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 384us/step - loss: 0.6906 - acc: 0.7440 - val_loss: 0.8149 - val_acc: 0.6871
# Q 249*464 T 115536 ☒ 111556
# Q 22*250  T 5500   ☒ 5700
# Q 517*83  T 42911  ☒ 42171
# Q 881*47  T 41407  ☒ 41227
# Q 855*565 T 483075 ☒ 481725
# Q 54*332  T 17928  ☒ 17628
# Q 104*417 T 43368  ☒ 48928
# Q 59*931  T 54929  ☒ 55849
# Q 90*25   T 2250   ☑ 2250
# Q 118*317 T 37406  ☒ 38026
#
# --------------------------------------------------
# Iteration 95
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 383us/step - loss: 0.7040 - acc: 0.7365 - val_loss: 0.8237 - val_acc: 0.6840
# Q 976*981 T 957456 ☒ 996146
# Q 78*491  T 38298  ☒ 38838
# Q 898*11  T 9878   ☒ 9558
# Q 659*77  T 50743  ☒ 51283
# Q 28*130  T 3640   ☒ 3820
# Q 264*32  T 8448   ☒ 8288
# Q 10*125  T 1250   ☑ 1250
# Q 393*536 T 210648 ☒ 216368
# Q 53*239  T 12667  ☒ 12987
# Q 406*627 T 254562 ☒ 254082
#
# --------------------------------------------------
# Iteration 96
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 379us/step - loss: 0.6849 - acc: 0.7462 - val_loss: 0.8155 - val_acc: 0.6919
# Q 635*35  T 22225  ☒ 21175
# Q 788*513 T 404244 ☒ 409404
# Q 901*15  T 13515  ☒ 13955
# Q 106*679 T 71974  ☒ 74664
# Q 505*8   T 4040   ☒ 4020
# Q 83*580  T 48140  ☑ 48140
# Q 181*45  T 8145   ☒ 8195
# Q 722*38  T 27436  ☒ 27276
# Q 34*13   T 442    ☑ 442
# Q 152*95  T 14440  ☒ 14320
#
# --------------------------------------------------
# Iteration 97
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 378us/step - loss: 0.6811 - acc: 0.7479 - val_loss: 0.8315 - val_acc: 0.6788
# Q 995*998 T 993010 ☒ 960130
# Q 98*85   T 8330   ☑ 8330
# Q 448*65  T 29120  ☒ 29320
# Q 308*456 T 140448 ☒ 137228
# Q 256*7   T 1792   ☒ 1832
# Q 96*269  T 25824  ☒ 26904
# Q 970*7   T 6790   ☒ 6990
# Q 373*957 T 356961 ☒ 355141
# Q 420*36  T 15120  ☒ 15720
# Q 59*76   T 4484   ☒ 4504
#
# --------------------------------------------------
# Iteration 98
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 377us/step - loss: 0.6836 - acc: 0.7465 - val_loss: 0.8436 - val_acc: 0.6782
# Q 658*36  T 23688  ☒ 23228
# Q 66*634  T 41844  ☒ 41524
# Q 401*811 T 325211 ☒ 329511
# Q 610*932 T 568520 ☒ 565320
# Q 15*197  T 2955   ☒ 3145
# Q 332*1   T 332    ☒ 392
# Q 370*86  T 31820  ☒ 31420
# Q 460*92  T 42320  ☒ 42520
# Q 66*385  T 25410  ☒ 25570
# Q 437*236 T 103132 ☒ 102702
#
# --------------------------------------------------
# Iteration 99
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 380us/step - loss: 0.6810 - acc: 0.7487 - val_loss: 0.8397 - val_acc: 0.6814
# Q 820*7   T 5740   ☑ 5740
# Q 9*944   T 8496   ☒ 8836
# Q 18*550  T 9900   ☒ 10300
# Q 13*25   T 325    ☒ 375
# Q 719*638 T 458722 ☒ 450202
# Q 933*8   T 7464   ☒ 7544
# Q 459*69  T 31671  ☒ 31551
# Q 931*236 T 219716 ☒ 212366
# Q 272*81  T 22032  ☒ 21332
# Q 794*42  T 33348  ☒ 33468

# %%
### plot loss and val_loss of each models together
import matplotlib.pyplot as plt

# loss_RMS_noDO = loss.copy()
# vl_RMS_noDO = val_loss.copy()
# vr_RMS_noDO = val_ratio.copy()

# plt.plot(loss_RV, color = 'tab:blue', linestyle='dashed')
# plt.plot(vl_RV, color = 'tab:blue')
# # plt.plot(vr_RV, color = 'tab:blue')

# plt.plot(loss_LBD, color = 'tab:red', linestyle='dashed')
# plt.plot(vl_LBD, color = 'tab:red')
# # plt.plot(vr_LBD, color = 'tab:red')

# plt.plot(loss_DO, color = 'tab:green', linestyle='dashed')
# plt.plot(vl_DO, color = 'tab:green')
# # plt.plot(vr_DO, color = 'tab:green')

# plt.plot(loss_RMS, color = 'xkcd:black', linestyle='dashed')
# plt.plot(vl_RMS, color = 'xkcd:black')
# # plt.plot(vr_RMS, color = 'xkcd:black')

# plt.plot(loss_RMS_noDO, color = 'xkcd:goldenrod', linestyle='dashed')
# plt.plot(vl_RMS_noDO, color = 'xkcd:goldenrod')
# # plt.plot(vr_RMS_noDO, color = 'xkcd:goldenrod')

# plt.legend(['RepeatValue_Adam', 'Lambda_Adam', 
#             'RepeatValue_Dropout_Adam', 'RepeatValue_Dropout_RMS',
#             'RepeatValue_Dropout_RMS'], color=['xkcd:black','xkcd:black','xkcd:black','xkcd:black','xkcd:black'], loc='upper right')

p1 = plt.plot(loss, color = 'xkcd:blue', linestyle='dashed')
p2 = plt.plot(val_loss, color = 'xkcd:blue')
p3 = plt.plot(val_ratio, color = 'xkcd:goldenrod')
p4 = plt.plot(acc, color = 'xkcd:green')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.title("Multiplication")
plt.legend((p1[0], p2[0], p3[0], p4[0]),
           ('train loss', 'val loss', 'val 10-sample acccuracy', 'model accuracy'))
plt.savefig('multply.png')
plt.show()

# %% [markdown]
# # Testing

# %%
print("MSG : Prediction")
#####################################################
## Try to test and evaluate your model ##############
## ex. test_x = ["555+175", "860+7  ", "340+29 "]
## ex. test_y = ["730 ", "867 ", "369 "] 
#####################################################
model.evaluate(test_x, test_y)
# Out:
# MSG : Prediction
# 60000/60000 [==============================] - 9s 157us/step
# [0.8514350372632344, 0.6739416665712993]

# %%
my_test_y = model.predict_classes(test_x)

correct_count = 0
for ind in range(test_y.shape[0]):
    rowy = test_y[np.array([ind])]

    preds = my_test_y[np.array([ind])]

    correct = ctable.decode(rowy[0])
    guess = ctable.decode(preds[0], calc_argmax=False)

    if correct == guess:
        correct_count += 1

print("test accuracy = ", correct_count / test_y.shape[0])
# Out:
# test accuracy =  0.08763333333333333
