# %%
from keras.models import Sequential
from keras import layers
from keras.models import Sequential
from keras.layers import LSTM, Dense, Lambda, Dropout, GRU, TimeDistributed
from keras.optimizers import Adam, RMSprop
import numpy as np
from six.moves import range
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Parameters Config

# %%
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
TRAINING_SIZE = 80000
DIGITS = 3
REVERSE = False
MAXLEN = DIGITS + 1 + DIGITS
chars = '0123456789+ '
RNN = layers.LSTM
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 1

# %%
class CharacterTable(object):
    def __init__(self, chars):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
    
    # one-hot
    def encode(self, C, num_rows):
        # x is 2D...
        x = np.zeros((num_rows, len(self.chars)))
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1  # why showing True/False below ?
        return x
    
    def decode(self, x, calc_argmax=True):
        if calc_argmax:
            x = x.argmax(axis=-1)
        return "".join(self.indices_char[i] for i in x)

# %%
ctable = CharacterTable(chars)

# %%
ctable.indices_char
# Out:
# {0: ' ',
#  1: '+',
#  2: '0',
#  3: '1',
#  4: '2',
#  5: '3',
#  6: '4',
#  7: '5',
#  8: '6',
#  9: '7',
#  10: '8',
#  11: '9'}

# %% [markdown]
# # Data Generation

# %%
# Generate the two lists, i.e. question and answer in p5 of the ppt

questions = []
expected = []
seen = set() #?

print('Generating data...')
while len(questions) < TRAINING_SIZE:
    
    # ?
    f = lambda: int(''.join(np.random.choice(list('0123456789')) for i in range(np.random.randint(1, DIGITS + 1))))
    a, b = f(), f()
    
    # avoid duplication
    key = tuple(sorted((a, b)))
    if key in seen:
        continue
    seen.add(key)
    
    q = '{}+{}'.format(a, b)
    query = q + ' ' * (MAXLEN - len(q))
    ans = str(a + b)
    ans += ' ' * (DIGITS + 1 - len(ans))
    
    # ?
    if REVERSE:
        query = query[::-1]
        
    questions.append(query)
    expected.append(ans)
    
print('Total addition questions:', len(questions))
# Out:
# Generating data...
# Total addition questions: 80000

# %%
print(questions[:5], expected[:5])
# Out:
# ['1+53   ', '60+98  ', '8+3    ', '556+369', '15+847 '] ['54  ', '158 ', '11  ', '925 ', '862 ']

# %% [markdown]
# # Processing

# %%
print('Vectorization...')
x = np.zeros((len(questions), MAXLEN, len(chars)), dtype=np.bool)
y = np.zeros((len(expected), DIGITS + 1, len(chars)), dtype=np.bool)

for i, sentence in enumerate(questions):
    x[i] = ctable.encode(sentence, MAXLEN)
for i, sentence in enumerate(expected):
    y[i] = ctable.encode(sentence, DIGITS + 1)
# Out:
# Vectorization...

# %%
# shuffle the data
indices = np.arange(len(y))
np.random.shuffle(indices)
x = x[indices]
y = y[indices]

# train_test_split
# take the first 20000 element
train_x = x[:20000]
train_y = y[:20000]
# take the elements other than first 20000
test_x = x[20000:]
test_y = y[20000:]

# val set is about 1/10 of the train set
split_at = len(train_x) - len(train_x) // 10
(x_train, x_val) = train_x[:split_at], train_x[split_at:]
(y_train, y_val) = train_y[:split_at], train_y[split_at:]

print('Training Data:')
print(x_train.shape)
print(y_train.shape)

print('Validation Data:')
print(x_val.shape)
print(y_val.shape)

print('Testing Data:')
print(test_x.shape)
print(test_y.shape)
# Out:
# Training Data:
# (18000, 7, 12)
# (18000, 4, 12)
# Validation Data:
# (2000, 7, 12)
# (2000, 4, 12)
# Testing Data:
# (60000, 7, 12)
# (60000, 4, 12)

# %%
print("input: ", x_train[:1], '\n\n', "label: ", y_train[:1])
# Out:
# input:  [[[False False False False False False False  True False False False
#    False]
#   [False False False False False False False False False False  True
#    False]
#   [False False False False False  True False False False False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False  True False False False False False False False
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [ True False False False False False False False False False False
#    False]]]
#
#  label:  [[[False False False False False False False  True False False False
#    False]
#   [False False False False False False False False False False False
#     True]
#   [False False False False False False False False False False False
#     True]
#   [ True False False False False False False False False False False
#    False]]]

# %% [markdown]
# # Build Model

# %%
print('Build model...')

############################################
##### Build your own model here ############
############################################
model = Sequential()
model.add(LSTM(HIDDEN_SIZE, input_shape=(MAXLEN, len(chars))))
model.add(layers.RepeatVector(DIGITS + 1))
# model.add(Lambda(lambda x: x[:, -(DIGITS + 1):, :]))
model.add(LSTM(HIDDEN_SIZE, return_sequences=True))
model.add(TimeDistributed(Dense(len(chars), activation='softmax')))
optimizer = Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer,
              metrics=['accuracy'])

model.summary()
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 128)               72192
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 4, 128)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 4, 128)            131584
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 4, 12)             1548
# =================================================================
# Total params: 205,324
# Trainable params: 205,324
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss = list()
val_loss = list()
val_ratio = list()

# %% [markdown]
# # Training

# %%
for iteration in range(100):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    
    history = model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=1,
              validation_data=(x_val, y_val))
    loss.append(history.history['loss'][0])
    val_loss.append(history.history['val_loss'][0])
    
    # test on 10 datapoint in the val. set (1 per iter.)
    correct_count = 0
    for i in range(10):
        ind = np.random.randint(0, len(x_val))
        rowx, rowy = x_val[np.array([ind])], y_val[np.array([ind])]
        
        preds = model.predict_classes(rowx, verbose=0)
        
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        
        # as ppt p7
        print('Q', q[::-1] if REVERSE else q, end=' ')
        print('T', correct, end=' ')
        if correct == guess:
            print(colors.ok + '☑' + colors.close, end=' ')
            correct_count += 1
        else:
            print(colors.fail + '☒' + colors.close, end=' ')
        print(guess)
    val_ratio.append(correct_count / 10)
# Out:
# --------------------------------------------------
# Iteration 0
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 414us/step - loss: 2.0187 - acc: 0.2900 - val_loss: 1.8719 - val_acc: 0.3290
# Q 28+574  T 602  ☒ 133
# Q 270+63  T 333  ☒ 133
# Q 5+271   T 276  ☒ 13
# Q 450+8   T 458  ☒ 13
# Q 29+68   T 97   ☒ 135
# Q 742+75  T 817  ☒ 133
# Q 641+81  T 722  ☒ 135
# Q 93+224  T 317  ☒ 133
# Q 21+171  T 192  ☒ 135
# Q 302+9   T 311  ☒ 13
#
# --------------------------------------------------
# Iteration 1
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 278us/step - loss: 1.8566 - acc: 0.3298 - val_loss: 1.8359 - val_acc: 0.3396
# Q 876+315 T 1191 ☒ 100
# Q 39+51   T 90   ☒ 13
# Q 288+271 T 559  ☒ 100
# Q 30+100  T 130  ☒ 133
# Q 45+498  T 543  ☒ 103
# Q 30+531  T 561  ☒ 133
# Q 102+171 T 273  ☒ 133
# Q 358+813 T 1171 ☒ 100
# Q 14+950  T 964  ☒ 103
# Q 123+85  T 208  ☒ 133
#
# --------------------------------------------------
# Iteration 2
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 286us/step - loss: 1.8121 - acc: 0.3300 - val_loss: 1.8078 - val_acc: 0.3430
# Q 886+578 T 1464 ☒ 1064
# Q 835+308 T 1143 ☒ 100
# Q 6+326   T 332  ☒ 33
# Q 537+58  T 595  ☒ 100
# Q 321+22  T 343  ☒ 33
# Q 427+89  T 516  ☒ 100
# Q 792+626 T 1418 ☒ 103
# Q 71+145  T 216  ☒ 337
# Q 948+66  T 1014 ☒ 104
# Q 712+343 T 1055 ☒ 113
#
# --------------------------------------------------
# Iteration 3
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 282us/step - loss: 1.7859 - acc: 0.3365 - val_loss: 1.7712 - val_acc: 0.3468
# Q 474+491 T 965  ☒ 133
# Q 6+641   T 647  ☒ 37
# Q 603+947 T 1550 ☒ 133
# Q 742+75  T 817  ☒ 103
# Q 125+690 T 815  ☒ 103
# Q 219+533 T 752  ☒ 103
# Q 68+469  T 537  ☒ 103
# Q 465+4   T 469  ☒ 37
# Q 66+701  T 767  ☒ 703
# Q 321+218 T 539  ☒ 333
#
# --------------------------------------------------
# Iteration 4
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 286us/step - loss: 1.7414 - acc: 0.3577 - val_loss: 1.6977 - val_acc: 0.3726
# Q 467+16  T 483  ☒ 466
# Q 683+4   T 687  ☒ 881
# Q 75+20   T 95   ☒ 11
# Q 907+481 T 1388 ☒ 1088
# Q 527+405 T 932  ☒ 100
# Q 64+241  T 305  ☒ 446
# Q 83+182  T 265  ☒ 901
# Q 638+82  T 720  ☒ 800
# Q 5+755   T 760  ☒ 561
# Q 314+420 T 734  ☒ 409
#
# --------------------------------------------------
# Iteration 5
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 1.6589 - acc: 0.3784 - val_loss: 1.6318 - val_acc: 0.3903
# Q 624+15  T 639  ☒ 537
# Q 0+704   T 704  ☒ 110
# Q 98+983  T 1081 ☒ 1088
# Q 7+936   T 943  ☒ 983
# Q 978+923 T 1901 ☒ 1888
# Q 29+43   T 72   ☒ 33
# Q 763+17  T 780  ☒ 733
# Q 193+244 T 437  ☒ 307
# Q 336+719 T 1055 ☒ 110
# Q 635+215 T 850  ☒ 107
#
# --------------------------------------------------
# Iteration 6
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 303us/step - loss: 1.5910 - acc: 0.4012 - val_loss: 1.5655 - val_acc: 0.4184
# Q 48+968  T 1016 ☒ 900
# Q 662+117 T 779  ☒ 770
# Q 288+699 T 987  ☒ 900
# Q 314+420 T 734  ☒ 477
# Q 9+503   T 512  ☒ 11
# Q 434+397 T 831  ☒ 400
# Q 155+41  T 196  ☒ 477
# Q 98+402  T 500  ☒ 440
# Q 519+67  T 586  ☒ 790
# Q 430+285 T 715  ☒ 477
#
# --------------------------------------------------
# Iteration 7
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 302us/step - loss: 1.5436 - acc: 0.4200 - val_loss: 1.5151 - val_acc: 0.4329
# Q 34+506  T 540  ☒ 490
# Q 814+25  T 839  ☒ 899
# Q 133+901 T 1034 ☒ 1109
# Q 25+285  T 310  ☒ 249
# Q 0+565   T 565  ☒ 661
# Q 180+85  T 265  ☒ 290
# Q 27+707  T 734  ☒ 799
# Q 23+681  T 704  ☒ 799
# Q 670+39  T 709  ☒ 792
# Q 130+709 T 839  ☒ 909
#
# --------------------------------------------------
# Iteration 8
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 303us/step - loss: 1.4943 - acc: 0.4383 - val_loss: 1.4653 - val_acc: 0.4494
# Q 960+587 T 1547 ☒ 1674
# Q 269+6   T 275  ☒ 27
# Q 5+482   T 487  ☒ 544
# Q 80+304  T 384  ☒ 434
# Q 82+88   T 170  ☒ 988
# Q 860+549 T 1409 ☒ 1444
# Q 493+654 T 1147 ☒ 1000
# Q 346+892 T 1238 ☒ 1333
# Q 56+636  T 692  ☒ 613
# Q 172+474 T 646  ☒ 703
#
# --------------------------------------------------
# Iteration 9
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 295us/step - loss: 1.4407 - acc: 0.4605 - val_loss: 1.4378 - val_acc: 0.4531
# Q 477+84  T 561  ☒ 532
# Q 914+686 T 1600 ☒ 1522
# Q 61+471  T 532  ☒ 672
# Q 99+996  T 1095 ☒ 1070
# Q 776+687 T 1463 ☒ 1477
# Q 814+25  T 839  ☒ 855
# Q 544+925 T 1469 ☒ 1495
# Q 912+370 T 1282 ☒ 1125
# Q 513+234 T 747  ☒ 775
# Q 2+294   T 296  ☒ 229
#
# --------------------------------------------------
# Iteration 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 303us/step - loss: 1.4006 - acc: 0.4741 - val_loss: 1.4061 - val_acc: 0.4689
# Q 73+51   T 124  ☒ 621
# Q 58+87   T 145  ☒ 155
# Q 591+647 T 1238 ☒ 1155
# Q 11+587  T 598  ☒ 625
# Q 732+12  T 744  ☒ 755
# Q 29+819  T 848  ☒ 820
# Q 0+888   T 888  ☒ 988
# Q 29+170  T 199  ☒ 299
# Q 142+82  T 224  ☒ 200
# Q 571+86  T 657  ☒ 645
#
# --------------------------------------------------
# Iteration 11
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 303us/step - loss: 1.3623 - acc: 0.4904 - val_loss: 1.3442 - val_acc: 0.4999
# Q 58+438  T 496  ☒ 414
# Q 969+469 T 1438 ☒ 1415
# Q 42+231  T 273  ☒ 344
# Q 68+652  T 720  ☒ 722
# Q 732+51  T 783  ☒ 788
# Q 296+843 T 1139 ☒ 1166
# Q 756+583 T 1339 ☒ 1496
# Q 4+805   T 809  ☒ 844
# Q 85+214  T 299  ☒ 212
# Q 997+521 T 1518 ☒ 1615
#
# --------------------------------------------------
# Iteration 12
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s 305us/step - loss: 1.3140 - acc: 0.5122 - val_loss: 1.3053 - val_acc: 0.5175
# Q 74+452  T 526  ☒ 510
# Q 90+153  T 243  ☒ 209
# Q 1+485   T 486  ☒ 484
# Q 62+172  T 234  ☒ 233
# Q 544+925 T 1469 ☒ 1459
# Q 64+35   T 99   ☒ 500
# Q 896+2   T 898  ☒ 988
# Q 296+4   T 300  ☒ 304
# Q 454+44  T 498  ☒ 599
# Q 9+278   T 287  ☒ 278
#
# --------------------------------------------------
# Iteration 13
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 320us/step - loss: 1.2762 - acc: 0.5278 - val_loss: 1.2851 - val_acc: 0.5247
# Q 25+853  T 878  ☒ 888
# Q 315+861 T 1176 ☒ 1151
# Q 164+44  T 208  ☒ 278
# Q 324+757 T 1081 ☒ 101
# Q 90+547  T 637  ☒ 542
# Q 918+604 T 1522 ☒ 1456
# Q 801+470 T 1271 ☒ 1256
# Q 808+20  T 828  ☒ 829
# Q 299+49  T 348  ☒ 366
# Q 67+523  T 590  ☒ 588
#
# --------------------------------------------------
# Iteration 14
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 331us/step - loss: 1.2415 - acc: 0.5408 - val_loss: 1.2357 - val_acc: 0.5449
# Q 28+983  T 1011 ☑ 1011
# Q 600+142 T 742  ☒ 721
# Q 256+547 T 803  ☒ 781
# Q 50+702  T 752  ☒ 782
# Q 166+93  T 259  ☒ 266
# Q 391+151 T 542  ☒ 421
# Q 213+55  T 268  ☒ 267
# Q 91+511  T 602  ☒ 612
# Q 169+48  T 217  ☒ 245
# Q 329+38  T 367  ☒ 308
#
# --------------------------------------------------
# Iteration 15
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 311us/step - loss: 1.2014 - acc: 0.5566 - val_loss: 1.2008 - val_acc: 0.5510
# Q 508+36  T 544  ☒ 503
# Q 648+27  T 675  ☒ 685
# Q 59+406  T 465  ☒ 495
# Q 421+48  T 469  ☒ 488
# Q 182+416 T 598  ☒ 533
# Q 130+122 T 252  ☒ 233
# Q 650+50  T 700  ☒ 600
# Q 427+89  T 516  ☒ 433
# Q 327+5   T 332  ☒ 339
# Q 21+353  T 374  ☒ 366
#
# --------------------------------------------------
# Iteration 16
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 314us/step - loss: 1.1637 - acc: 0.5699 - val_loss: 1.1651 - val_acc: 0.5631
# Q 555+354 T 909  ☒ 900
# Q 561+69  T 630  ☒ 645
# Q 58+87   T 145  ☒ 154
# Q 654+628 T 1282 ☒ 1297
# Q 302+69  T 371  ☒ 406
# Q 58+531  T 589  ☒ 586
# Q 221+633 T 854  ☒ 866
# Q 175+998 T 1173 ☒ 1170
# Q 941+861 T 1802 ☒ 1891
# Q 495+847 T 1342 ☒ 1366
#
# --------------------------------------------------
# Iteration 17
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 319us/step - loss: 1.1273 - acc: 0.5819 - val_loss: 1.1320 - val_acc: 0.5772
# Q 683+4   T 687  ☒ 141
# Q 972+789 T 1761 ☒ 1724
# Q 180+214 T 394  ☒ 419
# Q 892+8   T 900  ☒ 981
# Q 869+26  T 895  ☒ 816
# Q 193+455 T 648  ☒ 736
# Q 68+313  T 381  ☒ 390
# Q 958+49  T 1007 ☒ 101
# Q 298+378 T 676  ☒ 766
# Q 6+998   T 1004 ☒ 1066
#
# --------------------------------------------------
# Iteration 18
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 340us/step - loss: 1.0906 - acc: 0.5977 - val_loss: 1.0900 - val_acc: 0.5954
# Q 38+916  T 954  ☒ 966
# Q 890+807 T 1697 ☒ 1787
# Q 810+12  T 822  ☒ 820
# Q 451+981 T 1432 ☒ 1439
# Q 1+127   T 128  ☒ 117
# Q 775+61  T 836  ☒ 820
# Q 379+16  T 395  ☒ 309
# Q 21+171  T 192  ☒ 183
# Q 23+681  T 704  ☒ 793
# Q 429+34  T 463  ☒ 461
#
# --------------------------------------------------
# Iteration 19
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 356us/step - loss: 1.0468 - acc: 0.6143 - val_loss: 1.0610 - val_acc: 0.6036
# Q 818+17  T 835  ☒ 849
# Q 583+424 T 1007 ☒ 101
# Q 74+452  T 526  ☒ 523
# Q 63+239  T 302  ☒ 309
# Q 284+912 T 1196 ☒ 1210
# Q 248+68  T 316  ☒ 322
# Q 77+109  T 186  ☒ 287
# Q 153+982 T 1135 ☒ 1100
# Q 671+60  T 731  ☒ 737
# Q 4+236   T 240  ☒ 239
#
# --------------------------------------------------
# Iteration 20
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 340us/step - loss: 1.0104 - acc: 0.6281 - val_loss: 1.0367 - val_acc: 0.6094
# Q 100+855 T 955  ☒ 979
# Q 337+624 T 961  ☒ 989
# Q 36+225  T 261  ☒ 265
# Q 78+501  T 579  ☒ 589
# Q 53+970  T 1023 ☒ 1021
# Q 3+736   T 739  ☑ 739
# Q 127+34  T 161  ☒ 167
# Q 750+862 T 1612 ☒ 1509
# Q 354+256 T 610  ☒ 609
# Q 596+99  T 695  ☒ 685
#
# --------------------------------------------------
# Iteration 21
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 333us/step - loss: 0.9808 - acc: 0.6381 - val_loss: 0.9876 - val_acc: 0.6340
# Q 60+121  T 181  ☒ 188
# Q 327+691 T 1018 ☒ 1010
# Q 30+576  T 606  ☒ 506
# Q 5+707   T 712  ☒ 711
# Q 792+626 T 1418 ☒ 1426
# Q 636+55  T 691  ☒ 609
# Q 59+539  T 598  ☒ 595
# Q 83+241  T 324  ☒ 323
# Q 956+53  T 1009 ☒ 1018
# Q 367+788 T 1155 ☒ 1154
#
# --------------------------------------------------
# Iteration 22
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 343us/step - loss: 0.9357 - acc: 0.6570 - val_loss: 0.9525 - val_acc: 0.6409
# Q 912+370 T 1282 ☒ 1224
# Q 57+28   T 85   ☒ 80
# Q 25+941  T 966  ☑ 966
# Q 520+885 T 1405 ☒ 1306
# Q 821+3   T 824  ☒ 825
# Q 223+27  T 250  ☒ 259
# Q 325+844 T 1169 ☒ 1176
# Q 2+75    T 77   ☒ 79
# Q 56+33   T 89   ☒ 80
# Q 40+527  T 567  ☒ 571
#
# --------------------------------------------------
# Iteration 23
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 340us/step - loss: 0.8951 - acc: 0.6711 - val_loss: 0.9049 - val_acc: 0.6549
# Q 85+86   T 171  ☒ 183
# Q 409+44  T 453  ☒ 450
# Q 866+866 T 1732 ☒ 1736
# Q 747+34  T 781  ☑ 781
# Q 550+84  T 634  ☒ 635
# Q 636+16  T 652  ☒ 653
# Q 764+101 T 865  ☒ 877
# Q 16+87   T 103  ☒ 114
# Q 784+89  T 873  ☒ 872
# Q 337+276 T 613  ☒ 505
#
# --------------------------------------------------
# Iteration 24
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 337us/step - loss: 0.8482 - acc: 0.6882 - val_loss: 0.8550 - val_acc: 0.6793
# Q 81+964  T 1045 ☒ 1037
# Q 808+20  T 828  ☒ 819
# Q 838+15  T 853  ☒ 851
# Q 84+25   T 109  ☒ 119
# Q 12+549  T 561  ☒ 558
# Q 272+647 T 919  ☒ 939
# Q 900+83  T 983  ☒ 995
# Q 905+3   T 908  ☒ 915
# Q 289+4   T 293  ☒ 292
# Q 987+69  T 1056 ☒ 1055
#
# --------------------------------------------------
# Iteration 25
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 340us/step - loss: 0.7848 - acc: 0.7129 - val_loss: 0.7934 - val_acc: 0.6997
# Q 899+6   T 905  ☒ 106
# Q 18+636  T 654  ☑ 654
# Q 912+676 T 1588 ☒ 1688
# Q 634+196 T 830  ☒ 922
# Q 80+239  T 319  ☒ 329
# Q 7+76    T 83   ☒ 80
# Q 581+59  T 640  ☒ 641
# Q 34+456  T 490  ☑ 490
# Q 537+58  T 595  ☒ 605
# Q 213+55  T 268  ☒ 267
#
# --------------------------------------------------
# Iteration 26
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 342us/step - loss: 0.7340 - acc: 0.7288 - val_loss: 0.7475 - val_acc: 0.7098
# Q 36+807  T 843  ☑ 843
# Q 122+642 T 764  ☒ 766
# Q 315+861 T 1176 ☒ 1175
# Q 747+43  T 790  ☑ 790
# Q 81+839  T 920  ☒ 910
# Q 327+691 T 1018 ☒ 9000
# Q 164+63  T 227  ☒ 217
# Q 841+23  T 864  ☑ 864
# Q 517+91  T 608  ☒ 509
# Q 360+5   T 365  ☑ 365
#
# --------------------------------------------------
# Iteration 27
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 345us/step - loss: 0.6701 - acc: 0.7561 - val_loss: 0.6767 - val_acc: 0.7454
# Q 775+365 T 1140 ☒ 1129
# Q 166+221 T 387  ☑ 387
# Q 64+21   T 85   ☒ 76
# Q 952+298 T 1250 ☒ 1220
# Q 833+75  T 908  ☑ 908
# Q 615+31  T 646  ☑ 646
# Q 827+258 T 1085 ☒ 1075
# Q 46+170  T 216  ☒ 217
# Q 16+368  T 384  ☒ 374
# Q 358+57  T 415  ☑ 415
#
# --------------------------------------------------
# Iteration 28
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.6081 - acc: 0.7836 - val_loss: 0.6438 - val_acc: 0.7542
# Q 98+540  T 638  ☒ 639
# Q 987+69  T 1056 ☑ 1056
# Q 303+90  T 393  ☒ 300
# Q 259+718 T 977  ☒ 887
# Q 918+604 T 1522 ☒ 1632
# Q 919+666 T 1585 ☒ 1575
# Q 0+565   T 565  ☑ 565
# Q 0+565   T 565  ☑ 565
# Q 336+548 T 884  ☒ 883
# Q 46+815  T 861  ☑ 861
#
# --------------------------------------------------
# Iteration 29
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 345us/step - loss: 0.5545 - acc: 0.8087 - val_loss: 0.5674 - val_acc: 0.7970
# Q 377+7   T 384  ☒ 374
# Q 21+784  T 805  ☑ 805
# Q 41+778  T 819  ☒ 810
# Q 867+1   T 868  ☒ 878
# Q 90+547  T 637  ☒ 639
# Q 2+201   T 203  ☒ 212
# Q 108+332 T 440  ☒ 431
# Q 466+9   T 475  ☒ 575
# Q 20+373  T 393  ☑ 393
# Q 989+208 T 1197 ☑ 1197
#
# --------------------------------------------------
# Iteration 30
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 341us/step - loss: 0.5024 - acc: 0.8336 - val_loss: 0.5190 - val_acc: 0.8174
# Q 351+4   T 355  ☒ 345
# Q 487+43  T 530  ☒ 520
# Q 800+26  T 826  ☒ 836
# Q 556+311 T 867  ☒ 877
# Q 116+479 T 595  ☒ 585
# Q 68+313  T 381  ☑ 381
# Q 471+448 T 919  ☒ 910
# Q 882+316 T 1198 ☒ 1199
# Q 34+19   T 53   ☒ 54
# Q 343+494 T 837  ☑ 837
#
# --------------------------------------------------
# Iteration 31
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 436us/step - loss: 0.4566 - acc: 0.8567 - val_loss: 0.4786 - val_acc: 0.8380
# Q 454+584 T 1038 ☑ 1038
# Q 8+333   T 341  ☒ 340
# Q 4+236   T 240  ☒ 249
# Q 118+72  T 190  ☒ 180
# Q 981+713 T 1694 ☒ 1604
# Q 91+534  T 625  ☑ 625
# Q 936+808 T 1744 ☒ 1644
# Q 560+64  T 624  ☒ 625
# Q 379+0   T 379  ☑ 379
# Q 424+80  T 504  ☑ 504
#
# --------------------------------------------------
# Iteration 32
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 453us/step - loss: 0.4223 - acc: 0.8720 - val_loss: 0.4381 - val_acc: 0.8590
# Q 743+477 T 1220 ☑ 1220
# Q 912+676 T 1588 ☑ 1588
# Q 956+53  T 1009 ☒ 1019
# Q 555+23  T 578  ☑ 578
# Q 237+801 T 1038 ☒ 1078
# Q 95+840  T 935  ☒ 936
# Q 379+696 T 1075 ☒ 1066
# Q 366+37  T 403  ☑ 403
# Q 81+964  T 1045 ☑ 1045
# Q 437+337 T 774  ☒ 764
#
# --------------------------------------------------
# Iteration 33
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 458us/step - loss: 0.3789 - acc: 0.8931 - val_loss: 0.4007 - val_acc: 0.8763
# Q 0+743   T 743  ☑ 743
# Q 482+489 T 971  ☒ 970
# Q 911+247 T 1158 ☒ 1168
# Q 261+41  T 302  ☑ 302
# Q 674+43  T 717  ☑ 717
# Q 759+7   T 766  ☑ 766
# Q 25+285  T 310  ☒ 309
# Q 42+931  T 973  ☑ 973
# Q 46+170  T 216  ☑ 216
# Q 7+233   T 240  ☑ 240
#
# --------------------------------------------------
# Iteration 34
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 417us/step - loss: 0.3467 - acc: 0.9066 - val_loss: 0.3737 - val_acc: 0.8860
# Q 691+522 T 1213 ☒ 1212
# Q 59+664  T 723  ☑ 723
# Q 247+642 T 889  ☑ 889
# Q 560+684 T 1244 ☑ 1244
# Q 73+978  T 1051 ☑ 1051
# Q 356+97  T 453  ☒ 443
# Q 663+89  T 752  ☑ 752
# Q 680+12  T 692  ☒ 693
# Q 180+211 T 391  ☒ 381
# Q 436+507 T 943  ☒ 953
#
# --------------------------------------------------
# Iteration 35
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 458us/step - loss: 0.3189 - acc: 0.9170 - val_loss: 0.3626 - val_acc: 0.8869
# Q 829+717 T 1546 ☑ 1546
# Q 899+602 T 1501 ☒ 1400
# Q 649+517 T 1166 ☑ 1166
# Q 160+812 T 972  ☒ 871
# Q 31+72   T 103  ☒ 113
# Q 86+688  T 774  ☑ 774
# Q 28+204  T 232  ☒ 243
# Q 160+284 T 444  ☒ 445
# Q 39+705  T 744  ☑ 744
# Q 185+30  T 215  ☒ 206
#
# --------------------------------------------------
# Iteration 36
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.3025 - acc: 0.9208 - val_loss: 0.3583 - val_acc: 0.8810
# Q 319+25  T 344  ☑ 344
# Q 701+704 T 1405 ☒ 1415
# Q 760+614 T 1374 ☑ 1374
# Q 342+596 T 938  ☒ 948
# Q 104+925 T 1029 ☒ 1039
# Q 361+12  T 373  ☑ 373
# Q 688+1   T 689  ☑ 689
# Q 4+368   T 372  ☒ 362
# Q 31+970  T 1001 ☒ 101
# Q 966+39  T 1005 ☑ 1005
#
# --------------------------------------------------
# Iteration 37
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 373us/step - loss: 0.2738 - acc: 0.9313 - val_loss: 0.3054 - val_acc: 0.9110
# Q 88+27   T 115  ☑ 115
# Q 89+830  T 919  ☒ 929
# Q 776+687 T 1463 ☑ 1463
# Q 36+341  T 377  ☑ 377
# Q 826+128 T 954  ☑ 954
# Q 858+929 T 1787 ☑ 1787
# Q 52+34   T 86   ☑ 86
# Q 878+48  T 926  ☑ 926
# Q 776+431 T 1207 ☑ 1207
# Q 18+454  T 472  ☑ 472
#
# --------------------------------------------------
# Iteration 38
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 368us/step - loss: 0.2492 - acc: 0.9417 - val_loss: 0.2953 - val_acc: 0.9160
# Q 76+438  T 514  ☑ 514
# Q 764+101 T 865  ☑ 865
# Q 8+714   T 722  ☑ 722
# Q 801+1   T 802  ☒ 801
# Q 39+505  T 544  ☑ 544
# Q 7+936   T 943  ☑ 943
# Q 424+471 T 895  ☑ 895
# Q 261+54  T 315  ☑ 315
# Q 371+236 T 607  ☑ 607
# Q 362+634 T 996  ☒ 1076
#
# --------------------------------------------------
# Iteration 39
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.2299 - acc: 0.9485 - val_loss: 0.2802 - val_acc: 0.9186
# Q 26+656  T 682  ☑ 682
# Q 285+903 T 1188 ☒ 1288
# Q 567+95  T 662  ☑ 662
# Q 893+501 T 1394 ☑ 1394
# Q 9+141   T 150  ☑ 150
# Q 13+559  T 572  ☒ 573
# Q 238+85  T 323  ☑ 323
# Q 87+844  T 931  ☑ 931
# Q 531+971 T 1502 ☑ 1502
# Q 23+51   T 74   ☑ 74
#
# --------------------------------------------------
# Iteration 40
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.2118 - acc: 0.9539 - val_loss: 0.2551 - val_acc: 0.9293
# Q 41+862  T 903  ☒ 803
# Q 198+199 T 397  ☒ 387
# Q 12+613  T 625  ☑ 625
# Q 22+755  T 777  ☑ 777
# Q 25+343  T 368  ☑ 368
# Q 905+298 T 1203 ☒ 1103
# Q 450+8   T 458  ☑ 458
# Q 198+199 T 397  ☒ 387
# Q 519+97  T 616  ☑ 616
# Q 96+975  T 1071 ☑ 1071
#
# --------------------------------------------------
# Iteration 41
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 356us/step - loss: 0.1958 - acc: 0.9589 - val_loss: 0.2291 - val_acc: 0.9399
# Q 364+85  T 449  ☑ 449
# Q 66+968  T 1034 ☑ 1034
# Q 680+12  T 692  ☒ 792
# Q 21+784  T 805  ☑ 805
# Q 364+65  T 429  ☑ 429
# Q 318+507 T 825  ☒ 835
# Q 46+224  T 270  ☑ 270
# Q 47+321  T 368  ☑ 368
# Q 13+809  T 822  ☑ 822
# Q 988+922 T 1910 ☑ 1910
#
# --------------------------------------------------
# Iteration 42
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 352us/step - loss: 0.1768 - acc: 0.9652 - val_loss: 0.2053 - val_acc: 0.9481
# Q 36+225  T 261  ☑ 261
# Q 724+8   T 732  ☑ 732
# Q 8+714   T 722  ☑ 722
# Q 421+9   T 430  ☒ 420
# Q 479+81  T 560  ☑ 560
# Q 92+674  T 766  ☒ 765
# Q 252+332 T 584  ☑ 584
# Q 993+241 T 1234 ☑ 1234
# Q 23+782  T 805  ☑ 805
# Q 104+642 T 746  ☑ 746
#
# --------------------------------------------------
# Iteration 43
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 360us/step - loss: 0.1586 - acc: 0.9711 - val_loss: 0.2102 - val_acc: 0.9436
# Q 769+99  T 868  ☑ 868
# Q 356+358 T 714  ☑ 714
# Q 462+30  T 492  ☑ 492
# Q 73+217  T 290  ☑ 290
# Q 190+28  T 218  ☑ 218
# Q 98+328  T 426  ☑ 426
# Q 96+191  T 287  ☒ 286
# Q 39+546  T 585  ☑ 585
# Q 39+880  T 919  ☑ 919
# Q 983+56  T 1039 ☑ 1039
#
# --------------------------------------------------
# Iteration 44
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 369us/step - loss: 0.1474 - acc: 0.9734 - val_loss: 0.2004 - val_acc: 0.9446
# Q 147+634 T 781  ☑ 781
# Q 124+64  T 188  ☑ 188
# Q 925+920 T 1845 ☑ 1845
# Q 168+693 T 861  ☑ 861
# Q 1+603   T 604  ☒ 605
# Q 2+294   T 296  ☑ 296
# Q 32+384  T 416  ☑ 416
# Q 308+578 T 886  ☑ 886
# Q 12+512  T 524  ☑ 524
# Q 41+566  T 607  ☑ 607
#
# --------------------------------------------------
# Iteration 45
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 363us/step - loss: 0.1374 - acc: 0.9755 - val_loss: 0.1865 - val_acc: 0.9467
# Q 550+81  T 631  ☑ 631
# Q 63+301  T 364  ☑ 364
# Q 8+181   T 189  ☑ 189
# Q 172+60  T 232  ☑ 232
# Q 546+296 T 842  ☑ 842
# Q 169+48  T 217  ☑ 217
# Q 125+202 T 327  ☑ 327
# Q 783+316 T 1099 ☑ 1099
# Q 46+348  T 394  ☒ 494
# Q 831+78  T 909  ☒ 919
#
# --------------------------------------------------
# Iteration 46
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.1413 - acc: 0.9713 - val_loss: 0.2075 - val_acc: 0.9374
# Q 86+18   T 104  ☑ 104
# Q 2+294   T 296  ☑ 296
# Q 4+236   T 240  ☑ 240
# Q 778+810 T 1588 ☒ 1589
# Q 98+986  T 1084 ☑ 1084
# Q 230+119 T 349  ☑ 349
# Q 225+621 T 846  ☑ 846
# Q 993+61  T 1054 ☑ 1054
# Q 777+908 T 1685 ☑ 1685
# Q 734+13  T 747  ☑ 747
#
# --------------------------------------------------
# Iteration 47
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 353us/step - loss: 0.1393 - acc: 0.9693 - val_loss: 0.1682 - val_acc: 0.9521
# Q 9+632   T 641  ☑ 641
# Q 75+197  T 272  ☑ 272
# Q 285+51  T 336  ☑ 336
# Q 867+1   T 868  ☑ 868
# Q 99+382  T 481  ☑ 481
# Q 43+640  T 683  ☑ 683
# Q 5+516   T 521  ☑ 521
# Q 408+683 T 1091 ☑ 1091
# Q 44+782  T 826  ☑ 826
# Q 11+338  T 349  ☑ 349
#
# --------------------------------------------------
# Iteration 48
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 356us/step - loss: 0.1081 - acc: 0.9830 - val_loss: 0.1497 - val_acc: 0.9608
# Q 94+949  T 1043 ☑ 1043
# Q 927+580 T 1507 ☒ 1407
# Q 159+177 T 336  ☑ 336
# Q 28+142  T 170  ☑ 170
# Q 46+106  T 152  ☑ 152
# Q 709+98  T 807  ☑ 807
# Q 412+639 T 1051 ☑ 1051
# Q 708+845 T 1553 ☑ 1553
# Q 91+993  T 1084 ☑ 1084
# Q 217+60  T 277  ☑ 277
#
# --------------------------------------------------
# Iteration 49
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 356us/step - loss: 0.1099 - acc: 0.9792 - val_loss: 0.1488 - val_acc: 0.9591
# Q 955+514 T 1469 ☒ 1479
# Q 528+914 T 1442 ☑ 1442
# Q 416+788 T 1204 ☑ 1204
# Q 7+940   T 947  ☑ 947
# Q 988+93  T 1081 ☑ 1081
# Q 743+354 T 1097 ☑ 1097
# Q 402+546 T 948  ☒ 958
# Q 2+731   T 733  ☑ 733
# Q 287+442 T 729  ☑ 729
# Q 123+85  T 208  ☑ 208
#
# --------------------------------------------------
# Iteration 50
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 399us/step - loss: 0.0914 - acc: 0.9869 - val_loss: 0.1377 - val_acc: 0.9645
# Q 49+39   T 88   ☑ 88
# Q 319+685 T 1004 ☒ 900
# Q 754+18  T 772  ☑ 772
# Q 357+272 T 629  ☑ 629
# Q 7+233   T 240  ☑ 240
# Q 98+983  T 1081 ☑ 1081
# Q 494+888 T 1382 ☒ 1383
# Q 816+92  T 908  ☒ 918
# Q 58+720  T 778  ☑ 778
# Q 677+85  T 762  ☑ 762
#
# --------------------------------------------------
# Iteration 51
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 433us/step - loss: 0.0873 - acc: 0.9872 - val_loss: 0.1429 - val_acc: 0.9646
# Q 495+847 T 1342 ☑ 1342
# Q 806+2   T 808  ☑ 808
# Q 22+739  T 761  ☑ 761
# Q 9+758   T 767  ☑ 767
# Q 67+625  T 692  ☑ 692
# Q 136+40  T 176  ☑ 176
# Q 636+16  T 652  ☑ 652
# Q 795+467 T 1262 ☑ 1262
# Q 672+805 T 1477 ☑ 1477
# Q 97+348  T 445  ☑ 445
#
# --------------------------------------------------
# Iteration 52
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 365us/step - loss: 0.0898 - acc: 0.9841 - val_loss: 0.1545 - val_acc: 0.9530
# Q 293+438 T 731  ☒ 741
# Q 756+644 T 1400 ☒ 1490
# Q 873+927 T 1800 ☒ 1890
# Q 298+378 T 676  ☑ 676
# Q 37+203  T 240  ☑ 240
# Q 62+302  T 364  ☑ 364
# Q 8+333   T 341  ☑ 341
# Q 87+826  T 913  ☑ 913
# Q 908+316 T 1224 ☑ 1224
# Q 48+110  T 158  ☑ 158
#
# --------------------------------------------------
# Iteration 53
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 365us/step - loss: 0.0893 - acc: 0.9828 - val_loss: 0.1621 - val_acc: 0.9501
# Q 106+123 T 229  ☑ 229
# Q 292+71  T 363  ☑ 363
# Q 73+831  T 904  ☑ 904
# Q 68+91   T 159  ☑ 159
# Q 731+541 T 1272 ☑ 1272
# Q 8+253   T 261  ☑ 261
# Q 270+603 T 873  ☒ 87
# Q 33+628  T 661  ☑ 661
# Q 61+471  T 532  ☑ 532
# Q 84+832  T 916  ☑ 916
#
# --------------------------------------------------
# Iteration 54
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 355us/step - loss: 0.0793 - acc: 0.9862 - val_loss: 0.1191 - val_acc: 0.9667
# Q 39+880  T 919  ☑ 919
# Q 254+446 T 700  ☒ 600
# Q 606+79  T 685  ☑ 685
# Q 220+63  T 283  ☑ 283
# Q 46+348  T 394  ☑ 394
# Q 727+298 T 1025 ☒ 1015
# Q 531+29  T 560  ☒ 550
# Q 56+833  T 889  ☑ 889
# Q 892+2   T 894  ☑ 894
# Q 410+591 T 1001 ☒ 901
#
# --------------------------------------------------
# Iteration 55
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 382us/step - loss: 0.0642 - acc: 0.9922 - val_loss: 0.1127 - val_acc: 0.9689
# Q 410+591 T 1001 ☒ 901
# Q 337+635 T 972  ☑ 972
# Q 117+54  T 171  ☑ 171
# Q 633+411 T 1044 ☑ 1044
# Q 4+336   T 340  ☑ 340
# Q 160+812 T 972  ☒ 971
# Q 214+21  T 235  ☑ 235
# Q 951+93  T 1044 ☑ 1044
# Q 526+8   T 534  ☑ 534
# Q 81+990  T 1071 ☑ 1071
#
# --------------------------------------------------
# Iteration 56
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 404us/step - loss: 0.0597 - acc: 0.9923 - val_loss: 0.1047 - val_acc: 0.9717
# Q 840+69  T 909  ☒ 919
# Q 15+67   T 82   ☑ 82
# Q 438+86  T 524  ☑ 524
# Q 22+27   T 49   ☑ 49
# Q 221+64  T 285  ☑ 285
# Q 960+587 T 1547 ☑ 1547
# Q 12+423  T 435  ☑ 435
# Q 383+457 T 840  ☑ 840
# Q 877+69  T 946  ☑ 946
# Q 6+349   T 355  ☑ 355
#
# --------------------------------------------------
# Iteration 57
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 367us/step - loss: 0.0664 - acc: 0.9884 - val_loss: 0.1262 - val_acc: 0.9640
# Q 421+9   T 430  ☒ 420
# Q 872+9   T 881  ☑ 881
# Q 62+960  T 1022 ☑ 1022
# Q 20+212  T 232  ☑ 232
# Q 977+24  T 1001 ☒ 1011
# Q 674+509 T 1183 ☑ 1183
# Q 710+90  T 800  ☒ 700
# Q 63+103  T 166  ☑ 166
# Q 455+44  T 499  ☑ 499
# Q 134+77  T 211  ☑ 211
#
# --------------------------------------------------
# Iteration 58
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 358us/step - loss: 0.0662 - acc: 0.9878 - val_loss: 0.1207 - val_acc: 0.9634
# Q 269+48  T 317  ☑ 317
# Q 384+36  T 420  ☑ 420
# Q 710+90  T 800  ☒ 700
# Q 36+829  T 865  ☑ 865
# Q 36+829  T 865  ☑ 865
# Q 979+44  T 1023 ☑ 1023
# Q 315+861 T 1176 ☑ 1176
# Q 962+893 T 1855 ☑ 1855
# Q 122+986 T 1108 ☑ 1108
# Q 8+129   T 137  ☑ 137
#
# --------------------------------------------------
# Iteration 59
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 365us/step - loss: 0.0977 - acc: 0.9738 - val_loss: 0.1071 - val_acc: 0.9692
# Q 560+64  T 624  ☑ 624
# Q 146+654 T 800  ☑ 800
# Q 207+724 T 931  ☑ 931
# Q 879+6   T 885  ☑ 885
# Q 993+241 T 1234 ☑ 1234
# Q 820+15  T 835  ☑ 835
# Q 517+91  T 608  ☑ 608
# Q 36+225  T 261  ☑ 261
# Q 117+54  T 171  ☑ 171
# Q 284+686 T 970  ☑ 970
#
# --------------------------------------------------
# Iteration 60
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 375us/step - loss: 0.0489 - acc: 0.9943 - val_loss: 0.0900 - val_acc: 0.9764
# Q 543+663 T 1206 ☑ 1206
# Q 560+64  T 624  ☑ 624
# Q 166+221 T 387  ☑ 387
# Q 57+496  T 553  ☑ 553
# Q 270+63  T 333  ☑ 333
# Q 46+597  T 643  ☑ 643
# Q 124+64  T 188  ☑ 188
# Q 273+508 T 781  ☑ 781
# Q 436+533 T 969  ☒ 979
# Q 40+782  T 822  ☒ 821
#
# --------------------------------------------------
# Iteration 61
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 363us/step - loss: 0.0420 - acc: 0.9960 - val_loss: 0.0853 - val_acc: 0.9771
# Q 20+352  T 372  ☑ 372
# Q 364+58  T 422  ☑ 422
# Q 931+887 T 1818 ☑ 1818
# Q 3+336   T 339  ☑ 339
# Q 82+765  T 847  ☑ 847
# Q 239+417 T 656  ☑ 656
# Q 163+39  T 202  ☑ 202
# Q 22+739  T 761  ☑ 761
# Q 4+4     T 8    ☑ 8
# Q 810+12  T 822  ☑ 822
#
# --------------------------------------------------
# Iteration 62
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 352us/step - loss: 0.0444 - acc: 0.9944 - val_loss: 0.0891 - val_acc: 0.9759
# Q 56+221  T 277  ☑ 277
# Q 39+705  T 744  ☑ 744
# Q 455+518 T 973  ☑ 973
# Q 672+805 T 1477 ☑ 1477
# Q 911+247 T 1158 ☑ 1158
# Q 62+960  T 1022 ☑ 1022
# Q 750+862 T 1612 ☑ 1612
# Q 26+312  T 338  ☑ 338
# Q 1+450   T 451  ☑ 451
# Q 28+144  T 172  ☑ 172
#
# --------------------------------------------------
# Iteration 63
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.0391 - acc: 0.9959 - val_loss: 0.0895 - val_acc: 0.9741
# Q 102+738 T 840  ☑ 840
# Q 805+48  T 853  ☒ 863
# Q 360+5   T 365  ☑ 365
# Q 282+15  T 297  ☑ 297
# Q 759+7   T 766  ☑ 766
# Q 166+221 T 387  ☑ 387
# Q 58+882  T 940  ☒ 930
# Q 55+588  T 643  ☑ 643
# Q 41+90   T 131  ☑ 131
# Q 714+6   T 720  ☑ 720
#
# --------------------------------------------------
# Iteration 64
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.1196 - acc: 0.9642 - val_loss: 0.1970 - val_acc: 0.9320
# Q 99+382  T 481  ☑ 481
# Q 156+75  T 231  ☑ 231
# Q 296+843 T 1139 ☒ 1149
# Q 55+329  T 384  ☑ 384
# Q 7+940   T 947  ☑ 947
# Q 153+982 T 1135 ☑ 1135
# Q 872+79  T 951  ☑ 951
# Q 53+702  T 755  ☑ 755
# Q 737+465 T 1202 ☑ 1202
# Q 110+33  T 143  ☑ 143
#
# --------------------------------------------------
# Iteration 65
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.0691 - acc: 0.9827 - val_loss: 0.0781 - val_acc: 0.9784
# Q 80+457  T 537  ☑ 537
# Q 792+33  T 825  ☑ 825
# Q 391+151 T 542  ☑ 542
# Q 159+177 T 336  ☑ 336
# Q 14+27   T 41   ☑ 41
# Q 640+13  T 653  ☑ 653
# Q 801+282 T 1083 ☑ 1083
# Q 515+922 T 1437 ☑ 1437
# Q 81+551  T 632  ☑ 632
# Q 81+184  T 265  ☑ 265
#
# --------------------------------------------------
# Iteration 66
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 358us/step - loss: 0.0317 - acc: 0.9977 - val_loss: 0.0697 - val_acc: 0.9814
# Q 70+91   T 161  ☑ 161
# Q 776+687 T 1463 ☑ 1463
# Q 21+526  T 547  ☑ 547
# Q 416+788 T 1204 ☑ 1204
# Q 431+923 T 1354 ☑ 1354
# Q 540+90  T 630  ☑ 630
# Q 29+819  T 848  ☑ 848
# Q 532+3   T 535  ☑ 535
# Q 648+27  T 675  ☑ 675
# Q 81+215  T 296  ☑ 296
#
# --------------------------------------------------
# Iteration 67
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.0285 - acc: 0.9983 - val_loss: 0.0740 - val_acc: 0.9806
# Q 49+550  T 599  ☑ 599
# Q 79+960  T 1039 ☑ 1039
# Q 84+970  T 1054 ☑ 1054
# Q 58+205  T 263  ☑ 263
# Q 366+37  T 403  ☑ 403
# Q 127+34  T 161  ☑ 161
# Q 12+808  T 820  ☑ 820
# Q 44+699  T 743  ☑ 743
# Q 450+8   T 458  ☑ 458
# Q 36+998  T 1034 ☑ 1034
#
# --------------------------------------------------
# Iteration 68
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 361us/step - loss: 0.0266 - acc: 0.9983 - val_loss: 0.0680 - val_acc: 0.9811
# Q 207+724 T 931  ☑ 931
# Q 9+121   T 130  ☑ 130
# Q 733+325 T 1058 ☑ 1058
# Q 98+983  T 1081 ☑ 1081
# Q 28+993  T 1021 ☑ 1021
# Q 881+747 T 1628 ☑ 1628
# Q 19+995  T 1014 ☒ 1015
# Q 86+376  T 462  ☑ 462
# Q 97+632  T 729  ☑ 729
# Q 688+81  T 769  ☑ 769
#
# --------------------------------------------------
# Iteration 69
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.0247 - acc: 0.9986 - val_loss: 0.0670 - val_acc: 0.9807
# Q 14+27   T 41   ☑ 41
# Q 139+878 T 1017 ☑ 1017
# Q 279+911 T 1190 ☑ 1190
# Q 379+33  T 412  ☑ 412
# Q 882+84  T 966  ☑ 966
# Q 292+71  T 363  ☑ 363
# Q 30+163  T 193  ☑ 193
# Q 63+429  T 492  ☑ 492
# Q 683+4   T 687  ☑ 687
# Q 133+901 T 1034 ☑ 1034
#
# --------------------------------------------------
# Iteration 70
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 355us/step - loss: 0.0237 - acc: 0.9986 - val_loss: 0.0672 - val_acc: 0.9802
# Q 289+16  T 305  ☑ 305
# Q 3+393   T 396  ☑ 396
# Q 518+530 T 1048 ☑ 1048
# Q 8+796   T 804  ☑ 804
# Q 832+5   T 837  ☑ 837
# Q 201+995 T 1196 ☑ 1196
# Q 629+908 T 1537 ☑ 1537
# Q 826+128 T 954  ☑ 954
# Q 594+53  T 647  ☑ 647
# Q 138+30  T 168  ☑ 168
#
# --------------------------------------------------
# Iteration 71
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 355us/step - loss: 0.0219 - acc: 0.9989 - val_loss: 0.0677 - val_acc: 0.9803
# Q 901+66  T 967  ☑ 967
# Q 112+775 T 887  ☑ 887
# Q 33+92   T 125  ☑ 125
# Q 776+431 T 1207 ☑ 1207
# Q 337+276 T 613  ☑ 613
# Q 703+424 T 1127 ☑ 1127
# Q 21+171  T 192  ☑ 192
# Q 926+249 T 1175 ☑ 1175
# Q 20+836  T 856  ☑ 856
# Q 862+8   T 870  ☒ 860
#
# --------------------------------------------------
# Iteration 72
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.0221 - acc: 0.9984 - val_loss: 0.0744 - val_acc: 0.9770
# Q 704+85  T 789  ☑ 789
# Q 712+343 T 1055 ☑ 1055
# Q 460+97  T 557  ☑ 557
# Q 56+833  T 889  ☑ 889
# Q 851+87  T 938  ☑ 938
# Q 508+0   T 508  ☑ 508
# Q 40+527  T 567  ☑ 567
# Q 636+16  T 652  ☑ 652
# Q 945+889 T 1834 ☒ 1934
# Q 780+66  T 846  ☑ 846
#
# --------------------------------------------------
# Iteration 73
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.0223 - acc: 0.9983 - val_loss: 0.0709 - val_acc: 0.9802
# Q 20+448  T 468  ☑ 468
# Q 358+813 T 1171 ☑ 1171
# Q 6+641   T 647  ☑ 647
# Q 77+734  T 811  ☑ 811
# Q 13+831  T 844  ☑ 844
# Q 430+69  T 499  ☒ 599
# Q 660+991 T 1651 ☑ 1651
# Q 343+226 T 569  ☑ 569
# Q 66+103  T 169  ☑ 169
# Q 24+487  T 511  ☑ 511
#
# --------------------------------------------------
# Iteration 74
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 401us/step - loss: 0.0765 - acc: 0.9780 - val_loss: 0.1793 - val_acc: 0.9360
# Q 749+955 T 1704 ☒ 1714
# Q 76+647  T 723  ☑ 723
# Q 519+67  T 586  ☑ 586
# Q 12+808  T 820  ☒ 829
# Q 0+816   T 816  ☑ 816
# Q 45+498  T 543  ☑ 543
# Q 644+658 T 1302 ☑ 1302
# Q 54+234  T 288  ☑ 288
# Q 39+127  T 166  ☑ 166
# Q 217+60  T 277  ☒ 268
#
# --------------------------------------------------
# Iteration 75
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 361us/step - loss: 0.0608 - acc: 0.9827 - val_loss: 0.0834 - val_acc: 0.9731
# Q 9+632   T 641  ☑ 641
# Q 540+90  T 630  ☑ 630
# Q 886+680 T 1566 ☑ 1566
# Q 54+465  T 519  ☑ 519
# Q 539+558 T 1097 ☑ 1097
# Q 477+84  T 561  ☑ 561
# Q 559+610 T 1169 ☑ 1169
# Q 895+521 T 1416 ☑ 1416
# Q 96+356  T 452  ☑ 452
# Q 430+69  T 499  ☒ 599
#
# --------------------------------------------------
# Iteration 76
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 352us/step - loss: 0.0214 - acc: 0.9984 - val_loss: 0.0610 - val_acc: 0.9806
# Q 682+673 T 1355 ☑ 1355
# Q 97+701  T 798  ☑ 798
# Q 164+44  T 208  ☑ 208
# Q 688+81  T 769  ☑ 769
# Q 737+28  T 765  ☑ 765
# Q 820+15  T 835  ☑ 835
# Q 122+63  T 185  ☑ 185
# Q 877+69  T 946  ☑ 946
# Q 944+256 T 1200 ☒ 1100
# Q 74+267  T 341  ☑ 341
#
# --------------------------------------------------
# Iteration 77
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 361us/step - loss: 0.0165 - acc: 0.9994 - val_loss: 0.0592 - val_acc: 0.9819
# Q 691+522 T 1213 ☑ 1213
# Q 157+864 T 1021 ☑ 1021
# Q 27+570  T 597  ☑ 597
# Q 319+685 T 1004 ☑ 1004
# Q 15+839  T 854  ☑ 854
# Q 84+14   T 98   ☑ 98
# Q 387+255 T 642  ☑ 642
# Q 960+587 T 1547 ☑ 1547
# Q 528+914 T 1442 ☑ 1442
# Q 175+998 T 1173 ☑ 1173
#
# --------------------------------------------------
# Iteration 78
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.0152 - acc: 0.9994 - val_loss: 0.0597 - val_acc: 0.9809
# Q 209+998 T 1207 ☑ 1207
# Q 555+29  T 584  ☑ 584
# Q 77+942  T 1019 ☒ 1029
# Q 712+880 T 1592 ☒ 1692
# Q 118+72  T 190  ☑ 190
# Q 5+436   T 441  ☑ 441
# Q 39+542  T 581  ☑ 581
# Q 442+872 T 1314 ☑ 1314
# Q 98+283  T 381  ☑ 381
# Q 220+66  T 286  ☑ 286
#
# --------------------------------------------------
# Iteration 79
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 363us/step - loss: 0.0147 - acc: 0.9994 - val_loss: 0.0589 - val_acc: 0.9822
# Q 32+581  T 613  ☑ 613
# Q 21+353  T 374  ☑ 374
# Q 56+312  T 368  ☑ 368
# Q 0+478   T 478  ☑ 478
# Q 14+26   T 40   ☒ 30
# Q 83+923  T 1006 ☑ 1006
# Q 334+80  T 414  ☑ 414
# Q 493+654 T 1147 ☑ 1147
# Q 983+56  T 1039 ☑ 1039
# Q 14+188  T 202  ☑ 202
#
# --------------------------------------------------
# Iteration 80
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 391us/step - loss: 0.0143 - acc: 0.9993 - val_loss: 0.0570 - val_acc: 0.9829
# Q 124+64  T 188  ☑ 188
# Q 892+894 T 1786 ☑ 1786
# Q 961+208 T 1169 ☑ 1169
# Q 21+566  T 587  ☑ 587
# Q 9+139   T 148  ☑ 148
# Q 715+9   T 724  ☑ 724
# Q 598+90  T 688  ☑ 688
# Q 878+83  T 961  ☑ 961
# Q 485+754 T 1239 ☑ 1239
# Q 208+808 T 1016 ☑ 1016
#
# --------------------------------------------------
# Iteration 81
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 411us/step - loss: 0.0147 - acc: 0.9990 - val_loss: 0.0584 - val_acc: 0.9827
# Q 892+894 T 1786 ☑ 1786
# Q 88+27   T 115  ☑ 115
# Q 91+680  T 771  ☑ 771
# Q 12+423  T 435  ☑ 435
# Q 160+594 T 754  ☑ 754
# Q 9+758   T 767  ☑ 767
# Q 67+989  T 1056 ☑ 1056
# Q 466+88  T 554  ☑ 554
# Q 1+811   T 812  ☑ 812
# Q 43+965  T 1008 ☑ 1008
#
# --------------------------------------------------
# Iteration 82
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 355us/step - loss: 0.0347 - acc: 0.9936 - val_loss: 0.3884 - val_acc: 0.8844
# Q 16+408  T 424  ☑ 424
# Q 953+49  T 1002 ☒ 1012
# Q 799+55  T 854  ☒ 844
# Q 88+339  T 427  ☒ 527
# Q 124+64  T 188  ☑ 188
# Q 44+297  T 341  ☒ 441
# Q 6+985   T 991  ☑ 991
# Q 64+21   T 85   ☑ 85
# Q 17+747  T 764  ☑ 764
# Q 655+61  T 716  ☑ 716
#
# --------------------------------------------------
# Iteration 83
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.1381 - acc: 0.9535 - val_loss: 0.0962 - val_acc: 0.9692
# Q 554+552 T 1106 ☑ 1106
# Q 311+39  T 350  ☑ 350
# Q 67+536  T 603  ☑ 603
# Q 821+3   T 824  ☑ 824
# Q 481+133 T 614  ☑ 614
# Q 68+450  T 518  ☑ 518
# Q 74+267  T 341  ☑ 341
# Q 4+368   T 372  ☑ 372
# Q 905+58  T 963  ☑ 963
# Q 47+903  T 950  ☑ 950
#
# --------------------------------------------------
# Iteration 84
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.0210 - acc: 0.9973 - val_loss: 0.0736 - val_acc: 0.9771
# Q 74+878  T 952  ☑ 952
# Q 60+102  T 162  ☑ 162
# Q 465+4   T 469  ☑ 469
# Q 674+50  T 724  ☑ 724
# Q 55+84   T 139  ☑ 139
# Q 564+34  T 598  ☑ 598
# Q 269+48  T 317  ☑ 317
# Q 261+17  T 278  ☑ 278
# Q 437+337 T 774  ☑ 774
# Q 357+272 T 629  ☑ 629
#
# --------------------------------------------------
# Iteration 85
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.0221 - acc: 0.9967 - val_loss: 0.0681 - val_acc: 0.9784
# Q 48+543  T 591  ☑ 591
# Q 834+20  T 854  ☑ 854
# Q 749+32  T 781  ☑ 781
# Q 185+30  T 215  ☑ 215
# Q 5+994   T 999  ☑ 999
# Q 251+104 T 355  ☑ 355
# Q 80+48   T 128  ☑ 128
# Q 714+6   T 720  ☒ 710
# Q 187+33  T 220  ☒ 210
# Q 983+353 T 1336 ☑ 1336
#
# --------------------------------------------------
# Iteration 86
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 361us/step - loss: 0.0124 - acc: 0.9995 - val_loss: 0.0496 - val_acc: 0.9851
# Q 97+632  T 729  ☑ 729
# Q 444+30  T 474  ☑ 474
# Q 759+7   T 766  ☑ 766
# Q 778+810 T 1588 ☑ 1588
# Q 327+39  T 366  ☑ 366
# Q 134+77  T 211  ☑ 211
# Q 58+531  T 589  ☑ 589
# Q 853+96  T 949  ☒ 959
# Q 384+36  T 420  ☑ 420
# Q 5+11    T 16   ☑ 16
#
# --------------------------------------------------
# Iteration 87
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.0104 - acc: 0.9998 - val_loss: 0.0515 - val_acc: 0.9826
# Q 45+489  T 534  ☑ 534
# Q 907+50  T 957  ☑ 957
# Q 101+4   T 105  ☑ 105
# Q 154+73  T 227  ☑ 227
# Q 69+819  T 888  ☑ 888
# Q 20+996  T 1016 ☑ 1016
# Q 763+17  T 780  ☑ 780
# Q 8+714   T 722  ☑ 722
# Q 155+316 T 471  ☑ 471
# Q 454+44  T 498  ☑ 498
#
# --------------------------------------------------
# Iteration 88
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 360us/step - loss: 0.0098 - acc: 0.9998 - val_loss: 0.0490 - val_acc: 0.9845
# Q 51+325  T 376  ☑ 376
# Q 703+952 T 1655 ☑ 1655
# Q 113+888 T 1001 ☑ 1001
# Q 918+604 T 1522 ☑ 1522
# Q 964+967 T 1931 ☑ 1931
# Q 738+249 T 987  ☑ 987
# Q 9+632   T 641  ☑ 641
# Q 538+76  T 614  ☑ 614
# Q 15+18   T 33   ☑ 33
# Q 582+49  T 631  ☑ 631
#
# --------------------------------------------------
# Iteration 89
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.0093 - acc: 0.9997 - val_loss: 0.0525 - val_acc: 0.9835
# Q 92+830  T 922  ☑ 922
# Q 654+628 T 1282 ☑ 1282
# Q 623+13  T 636  ☑ 636
# Q 795+467 T 1262 ☑ 1262
# Q 387+255 T 642  ☑ 642
# Q 736+52  T 788  ☑ 788
# Q 68+313  T 381  ☑ 381
# Q 325+844 T 1169 ☑ 1169
# Q 815+955 T 1770 ☒ 1760
# Q 720+95  T 815  ☑ 815
#
# --------------------------------------------------
# Iteration 90
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.0087 - acc: 0.9999 - val_loss: 0.0502 - val_acc: 0.9836
# Q 537+5   T 542  ☑ 542
# Q 319+25  T 344  ☑ 344
# Q 46+879  T 925  ☑ 925
# Q 816+92  T 908  ☑ 908
# Q 13+101  T 114  ☑ 114
# Q 8+45    T 53   ☑ 53
# Q 9+265   T 274  ☑ 274
# Q 59+432  T 491  ☑ 491
# Q 97+348  T 445  ☑ 445
# Q 278+50  T 328  ☑ 328
#
# --------------------------------------------------
# Iteration 91
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 412us/step - loss: 0.0087 - acc: 0.9997 - val_loss: 0.0494 - val_acc: 0.9851
# Q 937+428 T 1365 ☑ 1365
# Q 751+30  T 781  ☑ 781
# Q 98+283  T 381  ☑ 381
# Q 358+813 T 1171 ☑ 1171
# Q 65+60   T 125  ☑ 125
# Q 63+958  T 1021 ☑ 1021
# Q 22+739  T 761  ☑ 761
# Q 732+51  T 783  ☑ 783
# Q 960+587 T 1547 ☑ 1547
# Q 788+553 T 1341 ☑ 1341
#
# --------------------------------------------------
# Iteration 92
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 356us/step - loss: 0.0084 - acc: 0.9997 - val_loss: 0.0544 - val_acc: 0.9820
# Q 987+9   T 996  ☑ 996
# Q 26+217  T 243  ☑ 243
# Q 13+212  T 225  ☑ 225
# Q 439+9   T 448  ☑ 448
# Q 94+663  T 757  ☑ 757
# Q 84+25   T 109  ☑ 109
# Q 924+15  T 939  ☑ 939
# Q 58+216  T 274  ☑ 274
# Q 115+114 T 229  ☑ 229
# Q 336+137 T 473  ☑ 473
#
# --------------------------------------------------
# Iteration 93
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.0080 - acc: 0.9997 - val_loss: 0.0485 - val_acc: 0.9845
# Q 983+71  T 1054 ☑ 1054
# Q 42+231  T 273  ☑ 273
# Q 674+509 T 1183 ☑ 1183
# Q 115+205 T 320  ☒ 310
# Q 165+11  T 176  ☑ 176
# Q 836+3   T 839  ☑ 839
# Q 77+109  T 186  ☑ 186
# Q 335+1   T 336  ☑ 336
# Q 64+875  T 939  ☑ 939
# Q 12+354  T 366  ☑ 366
#
# --------------------------------------------------
# Iteration 94
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 360us/step - loss: 0.0083 - acc: 0.9997 - val_loss: 0.0547 - val_acc: 0.9816
# Q 742+75  T 817  ☑ 817
# Q 399+797 T 1196 ☒ 1186
# Q 76+930  T 1006 ☑ 1006
# Q 220+66  T 286  ☑ 286
# Q 988+93  T 1081 ☑ 1081
# Q 46+879  T 925  ☑ 925
# Q 346+634 T 980  ☑ 980
# Q 127+34  T 161  ☑ 161
# Q 800+51  T 851  ☒ 841
# Q 630+266 T 896  ☑ 896
#
# --------------------------------------------------
# Iteration 95
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.0089 - acc: 0.9993 - val_loss: 0.0629 - val_acc: 0.9777
# Q 99+382  T 481  ☑ 481
# Q 619+171 T 790  ☑ 790
# Q 70+531  T 601  ☑ 601
# Q 80+329  T 409  ☑ 409
# Q 988+922 T 1910 ☑ 1910
# Q 520+51  T 571  ☑ 571
# Q 968+208 T 1176 ☑ 1176
# Q 8+194   T 202  ☑ 202
# Q 184+125 T 309  ☑ 309
# Q 674+43  T 717  ☑ 717
#
# --------------------------------------------------
# Iteration 96
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.0965 - acc: 0.9683 - val_loss: 0.1626 - val_acc: 0.9425
# Q 34+473  T 507  ☑ 507
# Q 144+2   T 146  ☑ 146
# Q 61+306  T 367  ☑ 367
# Q 477+84  T 561  ☑ 561
# Q 47+210  T 257  ☑ 257
# Q 225+90  T 315  ☑ 315
# Q 102+171 T 273  ☑ 273
# Q 755+997 T 1752 ☒ 1762
# Q 371+236 T 607  ☑ 607
# Q 36+341  T 377  ☑ 377
#
# --------------------------------------------------
# Iteration 97
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 362us/step - loss: 0.0812 - acc: 0.9726 - val_loss: 0.0901 - val_acc: 0.9689
# Q 385+87  T 472  ☑ 472
# Q 237+571 T 808  ☑ 808
# Q 84+832  T 916  ☑ 916
# Q 603+947 T 1550 ☑ 1550
# Q 9+592   T 601  ☑ 601
# Q 528+914 T 1442 ☒ 1452
# Q 343+494 T 837  ☑ 837
# Q 519+97  T 616  ☑ 616
# Q 674+43  T 717  ☑ 717
# Q 45+501  T 546  ☑ 546
#
# --------------------------------------------------
# Iteration 98
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 371us/step - loss: 0.0170 - acc: 0.9975 - val_loss: 0.0478 - val_acc: 0.9835
# Q 777+3   T 780  ☑ 780
# Q 427+89  T 516  ☑ 516
# Q 760+79  T 839  ☑ 839
# Q 59+811  T 870  ☑ 870
# Q 30+220  T 250  ☑ 250
# Q 84+545  T 629  ☑ 629
# Q 31+72   T 103  ☑ 103
# Q 596+99  T 695  ☑ 695
# Q 751+18  T 769  ☒ 779
# Q 780+66  T 846  ☑ 846
#
# --------------------------------------------------
# Iteration 99
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 370us/step - loss: 0.0082 - acc: 0.9998 - val_loss: 0.0450 - val_acc: 0.9853
# Q 487+43  T 530  ☑ 530
# Q 569+76  T 645  ☑ 645
# Q 73+978  T 1051 ☑ 1051
# Q 81+215  T 296  ☑ 296
# Q 16+87   T 103  ☑ 103
# Q 688+81  T 769  ☑ 769
# Q 44+810  T 854  ☑ 854
# Q 905+3   T 908  ☑ 908
# Q 977+30  T 1007 ☑ 1007
# Q 96+767  T 863  ☑ 863

# %%
### plot loss and val_loss of each models together
import matplotlib.pyplot as plt

# loss_RMS_noDO = loss.copy()
# vl_RMS_noDO = val_loss.copy()
# vr_RMS_noDO = val_ratio.copy()

# plt.plot(loss_RV, color = 'tab:blue', linestyle='dashed')
# plt.plot(vl_RV, color = 'tab:blue')
# # plt.plot(vr_RV, color = 'tab:blue')

# plt.plot(loss_LBD, color = 'tab:red', linestyle='dashed')
# plt.plot(vl_LBD, color = 'tab:red')
# # plt.plot(vr_LBD, color = 'tab:red')

# plt.plot(loss_DO, color = 'tab:green', linestyle='dashed')
# plt.plot(vl_DO, color = 'tab:green')
# # plt.plot(vr_DO, color = 'tab:green')

# plt.plot(loss_RMS, color = 'xkcd:black', linestyle='dashed')
# plt.plot(vl_RMS, color = 'xkcd:black')
# # plt.plot(vr_RMS, color = 'xkcd:black')

# plt.plot(loss_RMS_noDO, color = 'xkcd:goldenrod', linestyle='dashed')
# plt.plot(vl_RMS_noDO, color = 'xkcd:goldenrod')
# # plt.plot(vr_RMS_noDO, color = 'xkcd:goldenrod')

# plt.legend(['RepeatValue_Adam', 'Lambda_Adam', 
#             'RepeatValue_Dropout_Adam', 'RepeatValue_Dropout_RMS',
#             'RepeatValue_Dropout_RMS'], color=['xkcd:black','xkcd:black','xkcd:black','xkcd:black','xkcd:black'], loc='upper right')

plt.plot(loss, color = 'xkcd:blue', linestyle='dashed')
plt.plot(val_loss, color = 'xkcd:blue')
# plt.plot(vr_RMS_noDO, color = 'xkcd:goldenrod')
plt.show()

# %% [markdown]
# # Testing

# %%
print("MSG : Prediction")
#####################################################
## Try to test and evaluate your model ##############
## ex. test_x = ["555+175", "860+7  ", "340+29 "]
## ex. test_y = ["730 ", "867 ", "369 "] 
#####################################################
model.evaluate(test_x, test_y)
# Out:
# MSG : Prediction
# 60000/60000 [==============================] - 8s 133us/step
# [0.044021379792441924, 0.9855583333333333]

# %%
my_test_y = model.predict_classes(test_x)

correct_count = 0
for ind in range(test_y.shape[0]):
    rowy = test_y[np.array([ind])]

    preds = my_test_y[np.array([ind])]

    correct = ctable.decode(rowy[0])
    guess = ctable.decode(preds[0], calc_argmax=False)

    if correct == guess:
        correct_count += 1

print("test accuracy = ", correct_count / test_y.shape[0])
# Out:
# test accuracy =  0.9462166666666667
